# %%
#the dataset we will use is MNIST and USPS

#In this notebook we will implement the domain adversarial training of neural network

#the code is based on the paper "Domain-Adversarial Training of Neural Networks"
#also the architecture is same as the paper "Unsupervised Domain Adaptation by Backpropagation"

# %%
#we will use resnet50 as the base network
# we will use gradient reversal layer to implement the domain adversarial training
#we will implement gradient reversal layer at three different stages of the base
# classifier.

# %%
#first we will try to implement the gradient reversal layer at the end of the base classifier i.e. just before the fully connected layer and after the last feature extractor layer

# %%
experiment_name = 'mnist_dann'
version = 'v1'

#concat experiment name and version to get experiment id
experiment_id = experiment_name + '_' + version

model_path = 'saved_models/DANN'

# %%
#GPU name
#
GPU_NAME = 'cuda:1'

# %%
#neceassary imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable, Function
# from torchvision import datasets, transforms
from torch.utils.data import DataLoader, SubsetRandomSampler
import torch.utils.data as data
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torchvision.models as models
import torch.backends.cudnn as cudnn

import numpy as np

#import utils
import os
import itertools
import time
import copy
import random
import math

# %%
#imports for visualizations
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
from torchvision.models import resnet50, ResNet50_Weights
from torchvision.io import read_image
from torchsummary import summary
#import tenserboard
from torch.utils.tensorboard import SummaryWriter

# %%
#enable cudnn
cudnn.benchmark = True
# #cuda cache clear
# torch.cuda.empty_cache()

#set random seed
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %%
#device
device = torch.device(GPU_NAME if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=1)

# %%
#defining the hyperparameters
BATCH = 64

EPOCHS = 10
IMAGE_SIZE = 224
CHANNELS_IMG = 1
NUM_CLASSES = 10


C = 1   #weight of the domain loss
LAMBDA = 1 #scaling factor for the gradient reversal layer
GAMMA = 10

#parameters of ADAM optimizer
LEARNING_RATE = 0.001
BETA_1 = 0.9
BETA_2 = 0.999

#parameters of SGD optimizer with momentum
MOMENTUM = 0.9

# %% [markdown]
# # Utility functions

# %%
#define function to get one hot encoding of labels
def one_hot_encoding(label, total_classes=NUM_CLASSES):
    vect = torch.eye(total_classes)
    return vect[label]

# %%
#we will define optimizer scheduler

# %% [markdown]
# ## Model

# %%
## we will build 3 different models for implementing the domain adversarial training
#first be the feature extractor drived from resnet50
#second be a classifier after the feature extractor layer of resnet50
#third be the domain classifier with input as the feature vector from the feature extractor and output as the domain label

# %% [markdown]
# #### Base resnet50

# %%
#let us first build the feature extractor
#we input a resent50 model

#creating the model
weights = ResNet50_Weights.DEFAULT
#send weight sto gpu
# weights = weights.to(device)
#sending the model to GPU

base_resnet = resnet50(weights=weights).to(device)

# %%
#print model
base_resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
#we will change the first convolution layer to accept single channel image
#conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
# #if CHANNELS_IMG == 1:
# if CHANNELS_IMG == 1:
#     base_resnet.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)

# #change the last fully connected layer to output classes in NUM_CLASSES
# base_resnet.fc = nn.Linear(2048, NUM_CLASSES,  bias=True)

#write a function to changethe model based on number of channels and number of classes
def change_model(model, num_channels = CHANNELS_IMG, num_classes = NUM_CLASSES):
    if num_channels == 1:
        model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
    
    model.fc = nn.Linear(2048, num_classes,  bias=True)
    return model


base_resnet = change_model(base_resnet, num_channels = CHANNELS_IMG, num_classes = NUM_CLASSES)
base_resnet
# Out:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %%
#now we will write class for the feature extractor network
#we will pass the resnet50 model as the input to the class, and will use : nn.Sequential(*list(original_model.children())[:-2]) to get the feature extractor part of the model

class FeatureExtractor(nn.Module):
    def __init__(self, base_model):
        super(FeatureExtractor, self).__init__()
        # self.base_model = base_model
        self.feature_extractor = nn.Sequential(*list(base_model.children())[:-2])

    def forward(self, x):
        x = self.feature_extractor(x)
        return x

# %%
#now create an instance of the feature extractor and print the model
feature_extractor = FeatureExtractor(base_resnet).to(device)
feature_extractor
# Out:
# FeatureExtractor(
#   (feature_extractor): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
# )

# %%
#print summary of the model
#generate random pytorch tensor
# x = torch.randn(BATCH, CHANNELS_IMG, IMAGE_SIZE, IMAGE_SIZE).to(device)
#create x as (1, 1, 224, 224) random tensor
# x = torch.rand(1, 1, 224, 224).to(device)
#create numpy array of size (1, 1, 224, 224)
# x = np.random.rand(1, 1, IMAGE_SIZE, IMAGE_SIZE)
#convert numpy array to tensor
# x = torch.from_numpy(x).to(device)
#create x as (1, 1, 224, 224) random tensor
x = torch.rand( 224, 224).to(device)
#add batch dimension
x = x.unsqueeze(0)
#add channel dimension
x = x.unsqueeze(0)
#print x shape
print(x.shape)
#pass it through the model
y = feature_extractor(x)
#print y shape
print(y.shape)


# summary(feature_extractor, (CHANNELS_IMG, IMAGE_SIZE, IMAGE_SIZE))
# Out:
# torch.Size([1, 1, 224, 224])
# torch.Size([1, 2048, 7, 7])

# %%
# #create a random tensor and pass it through the feature extractor
# x = torch.randn(1, 1, 224, 224).to(device)
# out_feature_extractor = feature_extractor(x)
# out_feature_extractor.shape

# %%
# #now we will create the classifier, it will be same as the part of the resnet50 model after the feature extractor i.e. the last two layers of the resnet50 model
# #also the number of classes will be 10 as we have 10 classes in the MNIST dataset, the number of classes is stored in NUM_CLASSES

# class ClassClassifier(nn.Module):
#     def __init__(self, base_model, num_classes=NUM_CLASSES):
#         super(ClassClassifier, self).__init__()
#         self.num_classes = num_classes
#         self.classifier = nn.Sequential(*list(base_model.children())[-2:])

#     def forward(self, x):
#         #print the shape of the input
#         print("inside classifier: input shape",x.shape)
#         x = self.classifier(x)
#         # x = x.view(-1, self.num_classes)
#         return F.softmax(x)

# %%
#now we will create the classifier, it will be same as the part of the resnet50 model after the feature extractor i.e. the last two layers of the resnet50 model
#also the number of classes will be 10 as we have 10 classes in the MNIST dataset, the number of classes is stored in NUM_CLASSES

class ClassClassifier(nn.Module):
    def __init__(self, base_model):
        super(ClassClassifier, self).__init__()
        self.avgpool= nn.Sequential(*list(base_model.children())[-2:-1])
        self.flatten = nn.Flatten()
        self.fc = nn.Sequential(*list(base_model.children())[-1:])
        #define a flatten layer
        

    def forward(self, x):
        #print the shape of the input
        # print("inside classifier: input shape",x.shape)
        x = self.avgpool(x)

        x = self.flatten(x)

        x = self.fc(x)
        return F.softmax(x)

# %%
#create an instance of the classifier and print the model
class_classifier = ClassClassifier(base_resnet).to(device)
class_classifier
# Out:
# ClassClassifier(
#   (avgpool): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=10, bias=True)
#   )
# )

# %%
# print summary of the model
# summary(class_classifier, (2048, 1, 1))

# %%
# #pass the out_feature_extractor through the classifier
# out_classifier = classifier(out_feature_extractor)
# #print the shape of the output
# print("output shape", out_classifier.shape)
# # out_classifier.shape
# #print the output of the classifier
# print("output", out_classifier)

# %%
# # summary of the classifier
# #create 
# summary(classifier, (2048, 1, 1))

# %%
#let us write gradient reversal layer

class GradientReversalLayer(Function):
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.lambda_
        return output, None
    
    def grad_reverse(x, lambda_):
        return GradientReversalLayer.apply(x, lambda_)

# %%
#now we will create the domain classifier: named as DomainClassifier
#it will have the rest of the resnet model after the feature extractor and the classifier and will have an additional layer at the end to output the domain label: 0 for source and 1 for target
#it will have gradient reversal layer in between the feature extractor and the classifier, i.e the first layer of the domain classifier 
#it will be exactly same as ClassClassifier except for the last layer, which is not number of classes but 2 for domain labels and sigmoid activation function instead of softmax
#it will also do same [-2:] to get the classifier part of the model, first layer be gradient reversal layer

class DomainClassifier(nn.Module):
    def __init__(self, base_model):
        super(DomainClassifier, self).__init__()
        #first layer of the domain classifier be the gradient reversal layer

        self.avgpool = nn.Sequential(*list(base_model.children())[-2:-1])
        self.flatten = nn.Flatten()
        self.fc1 = nn.Sequential(nn.Linear(2048, 512, bias=True))
        self.fc2 = nn.Sequential(nn.Linear(512, 62, bias=True))
        self.fc3 = nn.Sequential(nn.Linear(62, 2, bias=True))
        
        #now add the last output layer
        # self.domain_classifier.add_module('domain_classifier_output', nn.Linear(2048, 2))
        #change the last layer to output 2 classes
        # self.fc = nn.Linear(2048, 2 , bias=True)

        #forward
    def forward(self, x, lambda_ = LAMBDA):
        x = GradientReversalLayer.grad_reverse(x, lambda_)
        x = self.avgpool(x)
        x = self.flatten(x)
        #output the domain label
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        # x = x.view(-1, 2)
        return F.softmax(x)

# %%
#create an instance of the domain classifier and print the model
domain_classifier = DomainClassifier(base_resnet).to(device)
domain_classifier
# Out:
# DomainClassifier(
#   (avgpool): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=512, out_features=62, bias=True)
#   )
#   (fc3): Sequential(
#     (0): Linear(in_features=62, out_features=2, bias=True)
#   )
# )

# %%
#print summary of the model
# summary(domain_classifier, (2048, 1, 1))

# %%
# #create an instance of the domain classifier and print the model
# domain_classifier = DomainClassifier(base_resnet).to(device)
# #pass the output of feature extractor through the domain classifier
# out_domain_classifier = domain_classifier(out_feature_extractor, 1)
# #print the shape of the output
# print("output shape", out_domain_classifier.shape)
# #print the output of the domain classifier
# print("output", out_domain_classifier)

# %% [markdown]
# ## Data-Processing

# %%
preprocess = weights.transforms()

# %%
#define the transform for the dataset
transform_mnist_resnet = transforms.Compose(
    [
  
    # if torch tensor then leave as it is, else convert to tensor
    transforms.Lambda(lambda x: x if isinstance(x, torch.Tensor) else transforms.functional.to_tensor(x)),
    #

    #resize to 224x224
    transforms.Resize(IMAGE_SIZE),

    #check if channels are 1, then convert to 3 channels
    transforms.Lambda(lambda x: x.repeat(3, 1, 1) if x.shape[0] == 1 else x),

    transforms.Lambda(lambda x: preprocess(x)),

    #if channels are 3, then make them 1
    transforms.Lambda(lambda x: x[0].unsqueeze(0) if x.shape[0] == 3 else x),
    
    # normalize
    transforms.Normalize(
            [0.5 for _ in range(CHANNELS_IMG)], [0.5 for _ in range(CHANNELS_IMG)]
        ),
    ]
)

# %% [markdown]
# #### Dataset

# %%
# for training we will use MNIST dataset in pytorch library
#for testing we will use USPS dataset

# %% [markdown]
# #### train data - MNIST
# #### test data - USPS

# %%
#load train data
train_data = datasets.MNIST(root='./data/', download=True, transform=transform_mnist_resnet) 
#load train data
train_loader = torch.utils.data.DataLoader(train_data, batch_size=BATCH, shuffle=True, num_workers=4)

# %%
#load test data
#USPS dataset
test_data = datasets.USPS(root='./data/', download=True, transform=transform_mnist_resnet)
#load test data
test_loader = torch.utils.data.DataLoader(test_data, batch_size=BATCH, shuffle=True, num_workers=4)

# %%
#print the length of train and test data
print(len(train_data))
#print the shape of train data
print(train_data[0][0].shape)
# Out:
# 60000
# torch.Size([1, 224, 224])

# %%
#print length of test data
print(len(test_data))
#print shape of test data
print(test_data[0][0].shape)
# Out:
# 7291
# torch.Size([1, 224, 224])

# %%
#print number of batches in train and test data
print(len(train_loader))
print(len(test_loader))
# Out:
# 938
# 114

# %%
# #we will test the model on the first batch of the train data, to test the dimensions of the output of the model and the loss function
# #we define a function to test the model
# def test_model(feature_extractor, class_classifier, loss_function):
#     #make the model sequential to pass the input through the feature extractor and then the output of feature extractor to the class classifier
#     # model = nn.Sequential(feature_extractor, class_classifier, loss_function)

#     #set model to eval mode
#     feature_extractor.eval()
#     class_classifier.eval()

#     #initialize the loss and number of correct predictions
#     loss = 0
#     correct = 0

#     #get the first batch of the train data
#     #wee use for and then break to get the first batch
#     for data, label in train_loader:

#         #print data shape
#         print("data shape", data.shape)
#         #print label shape
#         print("label shape", label.shape)
#         #print data type
#         print("data type", data.dtype)
#         #print label type
#         print("label type", label.dtype)
#         #print first label
#         print("first label", label[0])
#         #print all label
#         print("all label", label)


#         #move data and label to device
#         data, label = data.to(device), label.to(device)

#         #we measure the accuracy here
#         #get output from the model
#         # output = model(data)
#         #get the output from the feature extractor
#         feature = feature_extractor(data)
#         #print the shape of the feature
#         print("feature shape: ", feature.shape)
#         #print type of feature
#         print("feature type: ", type(feature))
#         #get the output from the class classifier
#         output = class_classifier(feature)
#         #print the shape of the output
#         print("output shape: ", output.shape)
#         #print type of output

#         #print output shape
#         print("output shape: ", output.shape)
#         #print output type
#         print("output type: ", type(output))

#         #get the loss
#         loss = loss_function(output, label)

#         #print loss
#         print("loss: ", loss)

#         #get the prediction
#         pred = output.argmax(dim=1, keepdim=True)
#         #print pred
#         print("pred: ", pred)
#         #update the correct predictions
#         correct = pred.eq(label.view_as(pred)).sum().item()

#         #print correct
#         print("correct: ", correct)
#         #accuracy
#         accuracy = correct / len(data)
#         #print accuracy
#         print("accuracy: ", accuracy)





#         #break
#         break

# #now we test the above function and build model and loss function
# #build the model
# #the classifier is composed of two models - feature extractor and classifier in sequence: input first passes through feature extractor and then the output of feature extractor is passed to classifier
# # and the output of classifier is the final output
# classifier = ClassClassifier(base_resnet, NUM_CLASSES).to(device)
# #build the feature extractor model from the class FeatureExtractor
# feature_extractor = FeatureExtractor(base_resnet).to(device)
# #now we make end to end model by combining the feature extractor and classifier
# # model = nn.Sequential(feature_extractor, classifier).to(device)
# #build the loss function
# loss_function = nn.CrossEntropyLoss().to(device)
# #test the model
# test_model(feature_extractor, classifier, loss_function)

# %%
#initialize tensorboard writer
#create writer for tensorboard
writer = SummaryWriter(f'runs/'+experiment_id)
# Out:
# 2022-11-08 18:04:03.371119: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
#write a save model function
#the arguments are the models, the optimizer, the epoch number, the model name
def save_model(feature_extractor, class_classifier, optimizer, epoch):
    #check if path exists, if not then create it
    #recursively check if each root directory exists, if not then recursively create each
    if not os.path.exists(model_path):
        os.makedirs(model_path)



    #we will save the model by the name of the experiment id and the epoch number
    torch.save(feature_extractor.state_dict(), f'{model_path}/{experiment_id}_feature_extractor_{epoch}.pth')
    torch.save(class_classifier.state_dict(), f'{model_path}/{experiment_id}_class_classifier_{epoch}.pth')
    torch.save(domain_classifier.state_dict(), f'{model_path}/{experiment_id}_domain_classifier_{epoch}.pth')

# %% [markdown]
# ## DANN Training

# %% [markdown]
# #### Pretraining Class Classifier and Domain classifers

# %%
#we will write a routine to make the class classifier to have optimal performance on the source domain
#this we call the pretrained model : as the class classifier is pretrained on the source domain
# this kind of initialization and
#better initialization would help the training to converge to a better solution

#funtion to train the model: feature extractor and class classifier on the source domain
#we make feature extractor non trainable
#only parameters of class classifier are trainable

# def

# %% [markdown]
# #### Test function

# %% [markdown]
# #### Source Domain Label : 0
# #### Target Domain Label : 1

# %%
#write a function to test the model, i.e. the class classifier on the test data
#the function takes as argument : the feature extractor, class classifier, domain classifier, test data loader 
def DANN_test(feature_extractor, class_classifier, domain_classifier, test_data_loader, dataset='TARGET'):
    #set the model to evaluation mode
    feature_extractor.eval()
    class_classifier.eval()
    domain_classifier.eval()

    #set the total and correct for class classifier to 0
    total_class_classifier = 0
    correct_class_classifier = 0
    #set the total and correct for domain classifier to 0
    total_domain_classifier = 0
    correct_domain_classifier = 0
    
    #set the writer
    # writer.add_scalar
 
    #loop through the test data loader
    with torch.no_grad():
        #loop through the test data loader
        for data, labels in test_data_loader:
            #get the data and labels
            data, labels = data.to(device), labels.to(device)
            #if dataset is target, then we will add the domain labels as 1
            if dataset == 'TARGET':
                domain_labels = torch.ones(data.size(0)).long().to(device)
            #if dataset is source, then we will add the domain labels as 0
            elif dataset == 'SOURCE':
                domain_labels = torch.zeros(data.size(0)).long().to(device)
                #if dataset is not source or target, then we will raise an error
            else:
                raise ValueError('Dataset must be source or target')
            #get the feature vector
            feature_vector = feature_extractor(data)
            #get the class classifier prediction
            class_classifier_pred = class_classifier(feature_vector)
            #get the domain classifier prediction
            domain_classifier_pred = domain_classifier(feature_vector)
   
            #get the predicted class
            _, predicted_class = torch.max(class_classifier_pred.data, 1)
            #get the total and correct for class classifier
            total_class_classifier += labels.size(0)
            correct_class_classifier += (predicted_class == labels).sum().item()
            #get the total and correct for domain classifier
            _, predicted_domain = torch.max(domain_classifier_pred.data, 1)
            total_domain_classifier += domain_labels.size(0)
            correct_domain_classifier += (predicted_domain == domain_labels).sum().item()
    #print the loss and accuracy
    print(dataset+'_'+'Test Accuracy Class Classifier: {}/{} ({:.0f}%)'.format(correct_class_classifier, total_class_classifier,
        100. * correct_class_classifier / total_class_classifier))
    print(dataset+'_'+'Test Accuracy Domain Classifier: {}/{} ({:.0f}%)'.format(correct_domain_classifier, total_domain_classifier,
        100. * correct_domain_classifier / total_domain_classifier))
    
    #write the loss and accuracy to the tensorboard
    writer.add_scalar(dataset+'Test_Class_Accuracy', 100. * correct_class_classifier / total_class_classifier, global_step=0)
    writer.add_scalar(dataset+'Test_Domain_Accuracy', 100. * correct_domain_classifier / total_domain_classifier, global_step=0)
    #close the writer
    writer.close()

# %%
#let us first see the models performance on the test data before training: so we can compare the performance before and after training
#test the model on the test data
DANN_test(feature_extractor, class_classifier, domain_classifier, test_loader, dataset='TARGET')
# Out:
# /tmp/ipykernel_29758/1062286346.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# /tmp/ipykernel_29758/2842852021.py:33: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# TARGET_Test Accuracy Class Classifier: 653/7291 (9%)
# TARGET_Test Accuracy Domain Classifier: 1339/7291 (18%)

# %%
#we will also test the model on the source data
DANN_test(feature_extractor, class_classifier, domain_classifier, train_loader, dataset='SOURCE')
# Out:
# /tmp/ipykernel_29758/1062286346.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# /tmp/ipykernel_29758/2842852021.py:33: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# SOURCE_Test Accuracy Class Classifier: 5606/60000 (9%)
# SOURCE_Test Accuracy Domain Classifier: 31012/60000 (52%)

# %%
# we will write a function for training the models as per DANN paper
#the arguments are: feature extractor, Class Classifier, Domain Classifier, source data loader, target data loader, number of epochs

#we will simultaneously track the loss and accuracy of the model on source and target data
#so we will store total corrects and total predictions for both source and target data


def DANN_training(feature_extractor, class_classifier, domain_classifier, source_data_loader, target_data_loader, num_epochs=EPOCHS, device = device):
    #for optimizer we will club all the parameters of all the models
    #we use Adam optimizer
    #the parameters of ADAM  are the standard ones for ADAM optimizer
    optimizer = optim.Adam(list(feature_extractor.parameters()) + list(class_classifier.parameters()) + list(domain_classifier.parameters()), lr=LEARNING_RATE, betas=(BETA_1, BETA_2))
    #we define the loss function for the domain classifier as cross entropy loss
    loss_fn_domain = nn.CrossEntropyLoss().to(device)
    #we define the loss function for the class classifier as cross entropy loss
    loss_fn_class = nn.CrossEntropyLoss().to(device)

    #we will iterate through datasets in a unique way, as we need one batch of source data and one batch of target data at a time to process through the models and then update the parameters
    #but we do not have same number of batches in source and target data
    #so we will first assume that source data has more batches than target data
    #write an assert statement to check if this is true
    # assert len(source_data_loader) >= len(target_data_loader), "Source data should have more batches than target data"
    #now we have source data to have more batches than target data, thus we will have 2 loops, one for source data and one for target data
    #the outer would be for source data and inner for target data
    #and we get the batch number of the source data from the outer loop and in the inner loop through the target data we will select the corresponding batch number of the target data 
    #, if the batch number is less than or equal to the minimum of the number of batches in source and target data,
    # else when we have exhausted the target data, we will start again from the first batch of the target data
    #we will do this untill we have exhausted the source data

    #we will keep track of the batch number of the source data in the outer loop
    batch_num_source = 0
    #we will keep track of the batch number of the target data in the inner loop
    batch_num_target = 0
    #we will keep track of the minimum of the number of batches in source and target data
    min_batches = min(len(source_data_loader), len(target_data_loader))
    #we will keep track of the number of batches in source data
    num_batches_source = len(source_data_loader)
    #we will keep track of the number of batches in target data
    num_batches_target = len(target_data_loader)

    #set all the models to train mode
    feature_extractor.train()
    class_classifier.train()
    domain_classifier.train()

    #variable to store the statistics of model training, like : loss, accuracy, etc
    epoch_tracker = 0   #it tracks the loop number
    batch_tracker = 0   #it tracks the batch number * epoch number
    #loss
    total_loss = 0
    total_class_loss = 0
    total_domain_loss = 0
    #accuracy
    total_class_classifier = 0
    correct_class_classifier = 0
    total_domain_classifier = 0
    correct_domain_classifier = 0

    best_epoch_accuracy = 0     #this will store the best epoch accuracy
    best_epoch = 0              #this will store the best epoch number

    #loop through the epochs
    for epoch in range(num_epochs):

        #if epoch is not 0, then we have values stored in epoch_total_class_classifier, epoch_total_class_correct, epoch_total_domain_classifier, epoch_total_domain_correct
        #so we will calculate the accuracy and loss for the previous epoch
        if epoch != 0:
            #calculate the accuracy
            epoch_accuracy_class_classifier = 100 * correct_class_classifier / total_class_classifier
            epoch_accuracy_domain_classifier = 100 * correct_domain_classifier / total_domain_classifier
            #calculate the loss, we divide total loss by batch_size, as we have added the loss for all the elements in the batch
            epoch_loss_class_classifier = total_class_loss /  batch_min_size
            epoch_loss_domain_classifier = total_domain_loss / batch_min_size
            #write the loss and accuracy to tensorboard
            writer.add_scalar('EPOCH_Train_Loss_class_classifier', epoch_loss_class_classifier, epoch_tracker)
            writer.add_scalar('EPOCH_Train_Loss_domain_classifier', epoch_loss_domain_classifier, epoch_tracker)
            writer.add_scalar('EPOCH_Train_Accuracy_class_classifier', epoch_accuracy_class_classifier, epoch_tracker)
            writer.add_scalar('EPOCH_Train_Accuracy_domain_classifier', epoch_accuracy_domain_classifier, epoch_tracker)

            #if the epoch_accuracy_domain_classifier is greater than best_epoch_accuracy, then we will update the best_epoch_accuracy and best_epoch
            if epoch_accuracy_domain_classifier > best_epoch_accuracy:
                best_epoch_accuracy = epoch_accuracy_domain_classifier
                best_epoch = epoch
                #we will save the model by the name of the experiment id and the epoch number
                #call the save_model function
                save_model(feature_extractor, class_classifier, domain_classifier, epoch)



            #increment the epoch tracker
            epoch_tracker += 1
            
          

        #epoch variable to track statistics in an epoch
        #loss
        epoch_total_loss = 0
        epoch_total_class_loss = 0
        epoch_total_domain_loss = 0
        #accuracy
        epoch_total_class_classifier = 0
        epoch_correct_class_classifier = 0
        epoch_total_domain_classifier = 0
        epoch_correct_domain_classifier = 0
        

        #start outer loop for source data
        for batch_idx_source, (source_,target_) in enumerate(zip(source_data_loader, target_data_loader)):
            #if the batch number of source data is less than the minimum of the number of batches in source and target data, then we will select the corresponding batch number of the target data
            # #we name that as batch_of_target
            # if batch_idx_source < min_batches:
            #     batch_of_target = batch_idx_source

            # #check if the batch_idx_source is equal to or greater than the minimum of the number of batches in source and target data
            # else:
            #     #if yes, then we will start again from the first batch of the target data
            #     batch_of_target = batch_idx_source % min_batches

        #start inner loop for target data
        # for batch_idx_target, (target_data, target_labels) in enumerate(target_data_loader):
            temp_total_class_classifier = 0
            temp_correct_class_classifier = 0
            temp_total_domain_classifier = 0
            temp_correct_domain_classifier = 0
            #now we will run the inner loop only when batch_idx_target is equal to the batch_of_target
            #in all else cases we will continue
            # if batch_idx_target != batch_of_target:
            #     continue

            #now we have one batch of source data and one batch of target data
            #now we run as if we are training a normal model with source data and target data in a single batch
            #send source data and target data to device
            source_data, source_labels = source_
            target_data, target_labels = target_
            source_data, source_labels = source_data.to(device), source_labels.to(device)
            target_data, target_labels = target_data.to(device), target_labels.to(device)

            #now we will calculate the lambda for gradient reversal layer: for current loop
            p = float(batch_idx_source + epoch *num_batches_source ) / num_epochs * num_batches_source
            lambda_ = 2. / (1. + np.exp(- GAMMA * p)) - 1

            #now we check that the number of images in source data and target data are same: i.e. batch size is same: this is particularly useful in case of last batch
            batch_min_size = min(source_data.shape[0], target_data.shape[0])
            #now we will select the same number of images from source and target data
            source_data = source_data[:batch_min_size]
            source_labels = source_labels[:batch_min_size]
            target_data = target_data[:batch_min_size]
            target_labels = target_labels[:batch_min_size]


            #zero grdient optimizer
            optimizer.zero_grad()

            #now we will create the domain labels for source and target data
            #this is required for the domain classifier
            #source domain label is 0
            source_domain_labels = torch.zeros(source_data.shape[0]).long().to(device)
            #target domain label is 1
            target_domain_labels = torch.ones(target_data.shape[0]).long().to(device)

            #now we will pass the source data and target data through the feature extractor
            source_features = feature_extractor(source_data)
            target_features = feature_extractor(target_data)

            #now we will calculate class prediction of source data
            source_class_pred = class_classifier(source_features)
            #now we calculate the loss for the class classifier
            class_classifier_loss = loss_fn_class(source_class_pred, source_labels)

            #now we will calculate the domain prediction of source data and target data
            source_domain_pred = domain_classifier(source_features, lambda_)
            target_domain_pred = domain_classifier(target_features, lambda_)
            #now we will calculate the loss for the domain classifier
            domain_classifier_loss = loss_fn_domain(source_domain_pred, source_domain_labels) + loss_fn_domain(target_domain_pred, target_domain_labels)

            #now we will calculate the total loss using the parameter: C
            total_loss = class_classifier_loss + C * domain_classifier_loss

            #now we will calculate the gradients
            total_loss.backward()
            #now we will update the parameters
            optimizer.step()

            #now we will calculate the accuracy of the class classifier
            _, predicted = torch.max(source_class_pred.data, 1)
            temp_total_class_classifier += source_labels.size(0)
            temp_correct_class_classifier += (predicted == source_labels).sum().item()
            #add the total and correct to total, correct and epoch_total, epoch_correct
            total_class_classifier += temp_total_class_classifier
            correct_class_classifier += temp_correct_class_classifier
            epoch_total_class_classifier += temp_total_class_classifier
            epoch_correct_class_classifier += temp_correct_class_classifier

            #now we will calculate the accuracy of the domain classifier
            _, predicted = torch.max(source_domain_pred.data, 1)
            temp_total_domain_classifier += source_domain_labels.size(0)
            temp_correct_domain_classifier += (predicted == source_domain_labels).sum().item()
            _, predicted = torch.max(target_domain_pred.data, 1)
            temp_total_domain_classifier += target_domain_labels.size(0)
            temp_correct_domain_classifier += (predicted == target_domain_labels).sum().item()
            #add the total and correct to total, correct and epoch_total, epoch_correct
            total_domain_classifier += temp_total_domain_classifier
            correct_domain_classifier += temp_correct_domain_classifier
            epoch_total_domain_classifier += temp_total_domain_classifier
            epoch_correct_domain_classifier += temp_correct_domain_classifier

            #now we will print the loss and accuracy based on the temp values
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tClass Loss: {:.6f}\tDomain Loss: {:.6f}\tClass Accuracy: {}/{} ({:.0f}%)\tDomain Accuracy: {}/{} ({:.0f}%)'.format(
                epoch, batch_idx_source * len(source_data), len(source_data_loader.dataset),
                100. * batch_idx_source / len(source_data_loader), class_classifier_loss.item(), domain_classifier_loss.item(),
                temp_correct_class_classifier, temp_total_class_classifier,
                100. * temp_correct_class_classifier / temp_total_class_classifier, temp_correct_domain_classifier, temp_total_domain_classifier,
                100. * temp_correct_domain_classifier / temp_total_domain_classifier))
            
            #we will also write the loss and accuracy to the tensorboard based on temp values
            writer.add_scalar('BATCH_Train_Class_Loss', class_classifier_loss.item(), global_step=batch_tracker)
            writer.add_scalar('BATCH_Train_Domain_Loss', domain_classifier_loss.item(), global_step=batch_tracker)
            writer.add_scalar('BATCH_Train_Class_Accuracy', 100. * temp_correct_class_classifier / temp_total_class_classifier, global_step=batch_tracker)
            writer.add_scalar('BATCH_Train_Domain_Accuracy', 100. * temp_correct_domain_classifier / temp_total_domain_classifier, global_step=batch_tracker)




            batch_tracker += 1

        #if epoch is 0 , then we will save the models and store best accuracy and epoch
        if epoch == 0:
            #save the model
            #call the save model function
            save_model(feature_extractor, class_classifier, domain_classifier, epoch)
            #store the best accuracy and epoch
            best_accuracy = 100. * epoch_correct_class_classifier / epoch_total_class_classifier
            best_epoch = epoch
    #now we will print the total accuracy for the training data
    #now we will print the total accuracy for the training data
    total_class_classifier_accuracy = 100. * correct_class_classifier / total_class_classifier
    total_domain_classifier_accuracy = 100. * correct_domain_classifier / total_domain_classifier
    print('Train Accuracy Class Classifier: {}/{} ({:.0f}%)'.format(correct_class_classifier, total_class_classifier, total_class_classifier_accuracy))
    print('Train Accuracy Domain Classifier: {}/{} ({:.0f}%)'.format(correct_domain_classifier, total_domain_classifier, total_domain_classifier_accuracy))
    #we will also write the loss and accuracy to the tensorboard based on total values
    writer.add_scalar('TOTAL_Train_Class_Accuracy', total_class_classifier_accuracy, global_step=0)
    writer.add_scalar('TOTAL_Train_Domain_Accuracy', total_domain_classifier_accuracy, global_step=0)
    #save the model
    #call the save model function
    save_model(feature_extractor, class_classifier, domain_classifier, epoch= EPOCHS)
    #print the best accuracy and epoch
    print('Best Accuracy: {:.0f}% at Epoch: {}'.format(best_epoch_accuracy, best_epoch))


    #close the writer
    writer.close()

    #return models
    return feature_extractor, class_classifier, domain_classifier

# %%
#
#test the function on the models and data
feature_extractor, class_classifier, domain_classifier = DANN_training(feature_extractor, class_classifier, domain_classifier,train_loader,test_loader)
# Out:
# /tmp/ipykernel_29758/1062286346.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# /tmp/ipykernel_29758/2842852021.py:33: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# Train Epoch: 0 [0/60000 (0%)]	Class Loss: 2.305610	Domain Loss: 1.387385	Class Accuracy: 1/64 (2%)	Domain Accuracy: 61/128 (48%)
# Train Epoch: 0 [64/60000 (0%)]	Class Loss: 2.292374	Domain Loss: 1.355520	Class Accuracy: 15/64 (23%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [128/60000 (0%)]	Class Loss: 2.293693	Domain Loss: 1.447083	Class Accuracy: 12/64 (19%)	Domain Accuracy: 40/128 (31%)
# Train Epoch: 0 [192/60000 (0%)]	Class Loss: 2.290832	Domain Loss: 1.678858	Class Accuracy: 16/64 (25%)	Domain Accuracy: 34/128 (27%)
# Train Epoch: 0 [256/60000 (0%)]	Class Loss: 2.296618	Domain Loss: 1.835315	Class Accuracy: 11/64 (17%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [320/60000 (1%)]	Class Loss: 2.294120	Domain Loss: 1.872056	Class Accuracy: 15/64 (23%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [384/60000 (1%)]	Class Loss: 2.296644	Domain Loss: 1.873385	Class Accuracy: 15/64 (23%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [448/60000 (1%)]	Class Loss: 2.300185	Domain Loss: 1.892886	Class Accuracy: 12/64 (19%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [512/60000 (1%)]	Class Loss: 2.300534	Domain Loss: 1.845768	Class Accuracy: 8/64 (12%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [576/60000 (1%)]	Class Loss: 2.301276	Domain Loss: 1.327751	Class Accuracy: 8/64 (12%)	Domain Accuracy: 55/128 (43%)
# Train Epoch: 0 [640/60000 (1%)]	Class Loss: 2.304505	Domain Loss: 1.409070	Class Accuracy: 7/64 (11%)	Domain Accuracy: 46/128 (36%)
# Train Epoch: 0 [704/60000 (1%)]	Class Loss: 2.314017	Domain Loss: 1.689029	Class Accuracy: 4/64 (6%)	Domain Accuracy: 45/128 (35%)
# Train Epoch: 0 [768/60000 (1%)]	Class Loss: 2.272577	Domain Loss: 1.790073	Class Accuracy: 8/64 (12%)	Domain Accuracy: 61/128 (48%)
# Train Epoch: 0 [832/60000 (1%)]	Class Loss: 2.287630	Domain Loss: 2.011643	Class Accuracy: 6/64 (9%)	Domain Accuracy: 27/128 (21%)
# Train Epoch: 0 [896/60000 (1%)]	Class Loss: 2.297458	Domain Loss: 1.993524	Class Accuracy: 7/64 (11%)	Domain Accuracy: 29/128 (23%)
# Train Epoch: 0 [960/60000 (2%)]	Class Loss: 2.256418	Domain Loss: 2.007426	Class Accuracy: 12/64 (19%)	Domain Accuracy: 28/128 (22%)
# Train Epoch: 0 [1024/60000 (2%)]	Class Loss: 2.242721	Domain Loss: 2.000821	Class Accuracy: 13/64 (20%)	Domain Accuracy: 27/128 (21%)
# Train Epoch: 0 [1088/60000 (2%)]	Class Loss: 2.160992	Domain Loss: 1.989385	Class Accuracy: 17/64 (27%)	Domain Accuracy: 44/128 (34%)
# Train Epoch: 0 [1152/60000 (2%)]	Class Loss: 2.183356	Domain Loss: 1.980487	Class Accuracy: 13/64 (20%)	Domain Accuracy: 51/128 (40%)
# Train Epoch: 0 [1216/60000 (2%)]	Class Loss: 2.152055	Domain Loss: 1.961244	Class Accuracy: 15/64 (23%)	Domain Accuracy: 63/128 (49%)
# Train Epoch: 0 [1280/60000 (2%)]	Class Loss: 2.129852	Domain Loss: 1.935916	Class Accuracy: 16/64 (25%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1344/60000 (2%)]	Class Loss: 2.189958	Domain Loss: 1.917267	Class Accuracy: 14/64 (22%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1408/60000 (2%)]	Class Loss: 2.161214	Domain Loss: 1.903376	Class Accuracy: 17/64 (27%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1472/60000 (2%)]	Class Loss: 2.149193	Domain Loss: 1.897505	Class Accuracy: 20/64 (31%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1536/60000 (3%)]	Class Loss: 2.180039	Domain Loss: 1.882261	Class Accuracy: 18/64 (28%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1600/60000 (3%)]	Class Loss: 2.143773	Domain Loss: 1.889606	Class Accuracy: 21/64 (33%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1664/60000 (3%)]	Class Loss: 2.164011	Domain Loss: 1.881127	Class Accuracy: 15/64 (23%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1728/60000 (3%)]	Class Loss: 2.156523	Domain Loss: 1.881349	Class Accuracy: 16/64 (25%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1792/60000 (3%)]	Class Loss: 2.051638	Domain Loss: 1.890843	Class Accuracy: 27/64 (42%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1856/60000 (3%)]	Class Loss: 2.065238	Domain Loss: 1.884213	Class Accuracy: 25/64 (39%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1920/60000 (3%)]	Class Loss: 2.097233	Domain Loss: 1.876719	Class Accuracy: 23/64 (36%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1984/60000 (3%)]	Class Loss: 2.035459	Domain Loss: 1.868453	Class Accuracy: 28/64 (44%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2048/60000 (3%)]	Class Loss: 1.928510	Domain Loss: 1.645788	Class Accuracy: 37/64 (58%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2112/60000 (4%)]	Class Loss: 2.011903	Domain Loss: 1.820704	Class Accuracy: 31/64 (48%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2176/60000 (4%)]	Class Loss: 2.002006	Domain Loss: 1.806098	Class Accuracy: 32/64 (50%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2240/60000 (4%)]	Class Loss: 1.979723	Domain Loss: 1.806155	Class Accuracy: 32/64 (50%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2304/60000 (4%)]	Class Loss: 1.850232	Domain Loss: 1.792224	Class Accuracy: 40/64 (62%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2368/60000 (4%)]	Class Loss: 1.939487	Domain Loss: 1.795461	Class Accuracy: 31/64 (48%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2432/60000 (4%)]	Class Loss: 1.917625	Domain Loss: 1.786082	Class Accuracy: 35/64 (55%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2496/60000 (4%)]	Class Loss: 1.814240	Domain Loss: 1.783594	Class Accuracy: 44/64 (69%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2560/60000 (4%)]	Class Loss: 1.871423	Domain Loss: 1.781119	Class Accuracy: 38/64 (59%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2624/60000 (4%)]	Class Loss: 1.806873	Domain Loss: 1.763705	Class Accuracy: 43/64 (67%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2688/60000 (4%)]	Class Loss: 1.867508	Domain Loss: 1.758051	Class Accuracy: 38/64 (59%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2752/60000 (5%)]	Class Loss: 1.798728	Domain Loss: 1.750652	Class Accuracy: 48/64 (75%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2816/60000 (5%)]	Class Loss: 1.781941	Domain Loss: 1.743930	Class Accuracy: 47/64 (73%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2880/60000 (5%)]	Class Loss: 1.709719	Domain Loss: 1.735035	Class Accuracy: 53/64 (83%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2944/60000 (5%)]	Class Loss: 1.762432	Domain Loss: 1.730832	Class Accuracy: 52/64 (81%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3008/60000 (5%)]	Class Loss: 1.684387	Domain Loss: 1.722103	Class Accuracy: 53/64 (83%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3072/60000 (5%)]	Class Loss: 1.666741	Domain Loss: 1.716714	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3136/60000 (5%)]	Class Loss: 1.633240	Domain Loss: 1.708554	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3200/60000 (5%)]	Class Loss: 1.649171	Domain Loss: 1.702409	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3264/60000 (5%)]	Class Loss: 1.644874	Domain Loss: 1.697601	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3328/60000 (6%)]	Class Loss: 1.625656	Domain Loss: 1.692040	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3392/60000 (6%)]	Class Loss: 1.622975	Domain Loss: 1.684158	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3456/60000 (6%)]	Class Loss: 1.623517	Domain Loss: 1.680637	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3520/60000 (6%)]	Class Loss: 1.590846	Domain Loss: 1.677047	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3584/60000 (6%)]	Class Loss: 1.552706	Domain Loss: 1.674800	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3648/60000 (6%)]	Class Loss: 1.538205	Domain Loss: 1.671406	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3712/60000 (6%)]	Class Loss: 1.553126	Domain Loss: 1.665467	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3776/60000 (6%)]	Class Loss: 1.502403	Domain Loss: 1.661618	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3840/60000 (6%)]	Class Loss: 1.548094	Domain Loss: 1.659841	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3904/60000 (7%)]	Class Loss: 1.575944	Domain Loss: 1.656547	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3968/60000 (7%)]	Class Loss: 1.580572	Domain Loss: 1.654166	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4032/60000 (7%)]	Class Loss: 1.642208	Domain Loss: 1.651214	Class Accuracy: 53/64 (83%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4096/60000 (7%)]	Class Loss: 1.544912	Domain Loss: 1.650403	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4160/60000 (7%)]	Class Loss: 1.518634	Domain Loss: 1.649520	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4224/60000 (7%)]	Class Loss: 1.555951	Domain Loss: 1.647969	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4288/60000 (7%)]	Class Loss: 1.540028	Domain Loss: 1.646493	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4352/60000 (7%)]	Class Loss: 1.570362	Domain Loss: 1.645163	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4416/60000 (7%)]	Class Loss: 1.509164	Domain Loss: 1.643786	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4480/60000 (7%)]	Class Loss: 1.496937	Domain Loss: 1.642776	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4544/60000 (8%)]	Class Loss: 1.544437	Domain Loss: 1.641299	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4608/60000 (8%)]	Class Loss: 1.501650	Domain Loss: 1.640833	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4672/60000 (8%)]	Class Loss: 1.543291	Domain Loss: 1.639889	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4736/60000 (8%)]	Class Loss: 1.511855	Domain Loss: 1.638577	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4800/60000 (8%)]	Class Loss: 1.542149	Domain Loss: 1.638487	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4864/60000 (8%)]	Class Loss: 1.570802	Domain Loss: 1.637526	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4928/60000 (8%)]	Class Loss: 1.554133	Domain Loss: 1.636777	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4992/60000 (8%)]	Class Loss: 1.530938	Domain Loss: 1.636372	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5056/60000 (8%)]	Class Loss: 1.595220	Domain Loss: 1.636181	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5120/60000 (9%)]	Class Loss: 1.578845	Domain Loss: 1.635554	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5184/60000 (9%)]	Class Loss: 1.548768	Domain Loss: 1.635118	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5248/60000 (9%)]	Class Loss: 1.498090	Domain Loss: 1.634666	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5312/60000 (9%)]	Class Loss: 1.526144	Domain Loss: 1.634422	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5376/60000 (9%)]	Class Loss: 1.583070	Domain Loss: 1.633711	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5440/60000 (9%)]	Class Loss: 1.536259	Domain Loss: 1.632358	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5504/60000 (9%)]	Class Loss: 1.514340	Domain Loss: 1.633185	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5568/60000 (9%)]	Class Loss: 1.516672	Domain Loss: 1.632988	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5632/60000 (9%)]	Class Loss: 1.544216	Domain Loss: 1.633011	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5696/60000 (9%)]	Class Loss: 1.563700	Domain Loss: 1.632326	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5760/60000 (10%)]	Class Loss: 1.571369	Domain Loss: 1.632560	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5824/60000 (10%)]	Class Loss: 1.502585	Domain Loss: 1.632196	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5888/60000 (10%)]	Class Loss: 1.543145	Domain Loss: 1.632136	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5952/60000 (10%)]	Class Loss: 1.520206	Domain Loss: 1.631946	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6016/60000 (10%)]	Class Loss: 1.521867	Domain Loss: 1.631636	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6080/60000 (10%)]	Class Loss: 1.521856	Domain Loss: 1.631693	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6144/60000 (10%)]	Class Loss: 1.613006	Domain Loss: 1.631389	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6208/60000 (10%)]	Class Loss: 1.528518	Domain Loss: 1.631327	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6272/60000 (10%)]	Class Loss: 1.489116	Domain Loss: 1.631064	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6336/60000 (11%)]	Class Loss: 1.494581	Domain Loss: 1.630880	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6400/60000 (11%)]	Class Loss: 1.511956	Domain Loss: 1.630516	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6464/60000 (11%)]	Class Loss: 1.538387	Domain Loss: 1.630661	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6528/60000 (11%)]	Class Loss: 1.540295	Domain Loss: 1.630620	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6592/60000 (11%)]	Class Loss: 1.513583	Domain Loss: 1.630421	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6656/60000 (11%)]	Class Loss: 1.575227	Domain Loss: 1.630453	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6720/60000 (11%)]	Class Loss: 1.566373	Domain Loss: 1.630272	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6784/60000 (11%)]	Class Loss: 1.577978	Domain Loss: 1.629651	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6848/60000 (11%)]	Class Loss: 1.535311	Domain Loss: 1.629892	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6912/60000 (12%)]	Class Loss: 1.517894	Domain Loss: 1.629714	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6976/60000 (12%)]	Class Loss: 1.526394	Domain Loss: 1.630034	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7040/60000 (12%)]	Class Loss: 1.691827	Domain Loss: 1.629939	Class Accuracy: 50/64 (78%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7104/60000 (12%)]	Class Loss: 1.532502	Domain Loss: 1.629906	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7168/60000 (12%)]	Class Loss: 1.559478	Domain Loss: 1.629900	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6667/60000 (12%)]	Class Loss: 1.588037	Domain Loss: 1.629728	Class Accuracy: 51/59 (86%)	Domain Accuracy: 59/118 (50%)
# Train Epoch: 1 [0/60000 (0%)]	Class Loss: 1.519311	Domain Loss: 1.629734	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [64/60000 (0%)]	Class Loss: 1.536985	Domain Loss: 1.629486	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [128/60000 (0%)]	Class Loss: 1.553550	Domain Loss: 1.629497	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [192/60000 (0%)]	Class Loss: 1.509672	Domain Loss: 1.629589	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [256/60000 (0%)]	Class Loss: 1.572124	Domain Loss: 1.629459	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [320/60000 (1%)]	Class Loss: 1.581147	Domain Loss: 1.629250	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [384/60000 (1%)]	Class Loss: 1.589970	Domain Loss: 1.629307	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [448/60000 (1%)]	Class Loss: 1.533339	Domain Loss: 1.629055	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [512/60000 (1%)]	Class Loss: 1.507066	Domain Loss: 1.629239	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [576/60000 (1%)]	Class Loss: 1.530787	Domain Loss: 1.629203	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [640/60000 (1%)]	Class Loss: 1.480349	Domain Loss: 1.629019	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [704/60000 (1%)]	Class Loss: 1.493753	Domain Loss: 1.628959	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [768/60000 (1%)]	Class Loss: 1.518460	Domain Loss: 1.628827	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [832/60000 (1%)]	Class Loss: 1.476726	Domain Loss: 1.628999	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [896/60000 (1%)]	Class Loss: 1.501665	Domain Loss: 1.628960	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [960/60000 (2%)]	Class Loss: 1.521191	Domain Loss: 1.628960	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1024/60000 (2%)]	Class Loss: 1.522222	Domain Loss: 1.628860	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1088/60000 (2%)]	Class Loss: 1.500627	Domain Loss: 1.628803	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1152/60000 (2%)]	Class Loss: 1.491099	Domain Loss: 1.628734	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1216/60000 (2%)]	Class Loss: 1.525699	Domain Loss: 1.628852	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1280/60000 (2%)]	Class Loss: 1.523465	Domain Loss: 1.628824	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1344/60000 (2%)]	Class Loss: 1.504614	Domain Loss: 1.628725	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1408/60000 (2%)]	Class Loss: 1.480964	Domain Loss: 1.628549	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1472/60000 (2%)]	Class Loss: 1.521036	Domain Loss: 1.628676	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1536/60000 (3%)]	Class Loss: 1.470387	Domain Loss: 1.628631	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1600/60000 (3%)]	Class Loss: 1.493326	Domain Loss: 1.628433	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1664/60000 (3%)]	Class Loss: 1.489732	Domain Loss: 1.628515	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1728/60000 (3%)]	Class Loss: 1.499207	Domain Loss: 1.628508	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1792/60000 (3%)]	Class Loss: 1.522361	Domain Loss: 1.628442	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1856/60000 (3%)]	Class Loss: 1.484756	Domain Loss: 1.628448	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1920/60000 (3%)]	Class Loss: 1.510596	Domain Loss: 1.628430	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [1984/60000 (3%)]	Class Loss: 1.507761	Domain Loss: 1.628405	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2048/60000 (3%)]	Class Loss: 1.489364	Domain Loss: 1.628442	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2112/60000 (4%)]	Class Loss: 1.477923	Domain Loss: 1.628304	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2176/60000 (4%)]	Class Loss: 1.513821	Domain Loss: 1.628333	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2240/60000 (4%)]	Class Loss: 1.545035	Domain Loss: 1.627812	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2304/60000 (4%)]	Class Loss: 1.617111	Domain Loss: 1.628291	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2368/60000 (4%)]	Class Loss: 1.538659	Domain Loss: 1.628197	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2432/60000 (4%)]	Class Loss: 1.535360	Domain Loss: 1.628262	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2496/60000 (4%)]	Class Loss: 1.503604	Domain Loss: 1.628201	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2560/60000 (4%)]	Class Loss: 1.484781	Domain Loss: 1.628214	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2624/60000 (4%)]	Class Loss: 1.541216	Domain Loss: 1.628193	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2688/60000 (4%)]	Class Loss: 1.483083	Domain Loss: 1.628143	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2752/60000 (5%)]	Class Loss: 1.478094	Domain Loss: 1.628177	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2816/60000 (5%)]	Class Loss: 1.486565	Domain Loss: 1.628129	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2880/60000 (5%)]	Class Loss: 1.495916	Domain Loss: 1.628075	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [2944/60000 (5%)]	Class Loss: 1.550175	Domain Loss: 1.628078	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3008/60000 (5%)]	Class Loss: 1.509654	Domain Loss: 1.628125	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3072/60000 (5%)]	Class Loss: 1.507758	Domain Loss: 1.628005	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3136/60000 (5%)]	Class Loss: 1.529644	Domain Loss: 1.628041	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3200/60000 (5%)]	Class Loss: 1.551197	Domain Loss: 1.627769	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3264/60000 (5%)]	Class Loss: 1.500501	Domain Loss: 1.628000	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3328/60000 (6%)]	Class Loss: 1.480333	Domain Loss: 1.627995	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3392/60000 (6%)]	Class Loss: 1.478169	Domain Loss: 1.627992	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3456/60000 (6%)]	Class Loss: 1.500454	Domain Loss: 1.627895	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3520/60000 (6%)]	Class Loss: 1.545868	Domain Loss: 1.627967	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3584/60000 (6%)]	Class Loss: 1.514773	Domain Loss: 1.627801	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3648/60000 (6%)]	Class Loss: 1.515682	Domain Loss: 1.627875	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3712/60000 (6%)]	Class Loss: 1.465891	Domain Loss: 1.627910	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3776/60000 (6%)]	Class Loss: 1.537098	Domain Loss: 1.627822	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3840/60000 (6%)]	Class Loss: 1.539748	Domain Loss: 1.627649	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3904/60000 (7%)]	Class Loss: 1.503160	Domain Loss: 1.627837	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [3968/60000 (7%)]	Class Loss: 1.511286	Domain Loss: 1.627795	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4032/60000 (7%)]	Class Loss: 1.478309	Domain Loss: 1.627739	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4096/60000 (7%)]	Class Loss: 1.469046	Domain Loss: 1.627815	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4160/60000 (7%)]	Class Loss: 1.501122	Domain Loss: 1.627680	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4224/60000 (7%)]	Class Loss: 1.537914	Domain Loss: 1.627742	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4288/60000 (7%)]	Class Loss: 1.538908	Domain Loss: 1.627774	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4352/60000 (7%)]	Class Loss: 1.475874	Domain Loss: 1.627688	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4416/60000 (7%)]	Class Loss: 1.512287	Domain Loss: 1.627664	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4480/60000 (7%)]	Class Loss: 1.507714	Domain Loss: 1.627589	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4544/60000 (8%)]	Class Loss: 1.486726	Domain Loss: 1.627659	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4608/60000 (8%)]	Class Loss: 1.508126	Domain Loss: 1.627537	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4672/60000 (8%)]	Class Loss: 1.499284	Domain Loss: 1.627665	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4736/60000 (8%)]	Class Loss: 1.549205	Domain Loss: 1.627495	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4800/60000 (8%)]	Class Loss: 1.527079	Domain Loss: 1.627574	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4864/60000 (8%)]	Class Loss: 1.486415	Domain Loss: 1.627591	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4928/60000 (8%)]	Class Loss: 1.549686	Domain Loss: 1.627571	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [4992/60000 (8%)]	Class Loss: 1.523879	Domain Loss: 1.627561	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5056/60000 (8%)]	Class Loss: 1.486469	Domain Loss: 1.627625	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5120/60000 (9%)]	Class Loss: 1.492135	Domain Loss: 1.627587	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5184/60000 (9%)]	Class Loss: 1.472637	Domain Loss: 1.627582	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5248/60000 (9%)]	Class Loss: 1.484956	Domain Loss: 1.627593	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5312/60000 (9%)]	Class Loss: 1.510626	Domain Loss: 1.627589	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5376/60000 (9%)]	Class Loss: 1.534056	Domain Loss: 1.627594	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5440/60000 (9%)]	Class Loss: 1.552332	Domain Loss: 1.627581	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5504/60000 (9%)]	Class Loss: 1.551167	Domain Loss: 1.627516	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5568/60000 (9%)]	Class Loss: 1.522368	Domain Loss: 1.627504	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5632/60000 (9%)]	Class Loss: 1.544016	Domain Loss: 1.627537	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5696/60000 (9%)]	Class Loss: 1.481499	Domain Loss: 1.627528	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5760/60000 (10%)]	Class Loss: 1.489327	Domain Loss: 1.627514	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5824/60000 (10%)]	Class Loss: 1.490708	Domain Loss: 1.627523	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5888/60000 (10%)]	Class Loss: 1.476190	Domain Loss: 1.627491	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [5952/60000 (10%)]	Class Loss: 1.488650	Domain Loss: 1.627491	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6016/60000 (10%)]	Class Loss: 1.508905	Domain Loss: 1.627459	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6080/60000 (10%)]	Class Loss: 1.504515	Domain Loss: 1.627458	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6144/60000 (10%)]	Class Loss: 1.507966	Domain Loss: 1.627449	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6208/60000 (10%)]	Class Loss: 1.542009	Domain Loss: 1.627445	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6272/60000 (10%)]	Class Loss: 1.493658	Domain Loss: 1.627392	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6336/60000 (11%)]	Class Loss: 1.494935	Domain Loss: 1.627417	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6400/60000 (11%)]	Class Loss: 1.499301	Domain Loss: 1.627417	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6464/60000 (11%)]	Class Loss: 1.539770	Domain Loss: 1.627404	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6528/60000 (11%)]	Class Loss: 1.544463	Domain Loss: 1.627421	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6592/60000 (11%)]	Class Loss: 1.462276	Domain Loss: 1.627408	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6656/60000 (11%)]	Class Loss: 1.491076	Domain Loss: 1.627396	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6720/60000 (11%)]	Class Loss: 1.495870	Domain Loss: 1.627425	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6784/60000 (11%)]	Class Loss: 1.500814	Domain Loss: 1.627327	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6848/60000 (11%)]	Class Loss: 1.503137	Domain Loss: 1.627415	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6912/60000 (12%)]	Class Loss: 1.462145	Domain Loss: 1.627442	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6976/60000 (12%)]	Class Loss: 1.498448	Domain Loss: 1.627476	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [7040/60000 (12%)]	Class Loss: 1.490806	Domain Loss: 1.627375	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [7104/60000 (12%)]	Class Loss: 1.493658	Domain Loss: 1.627354	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [7168/60000 (12%)]	Class Loss: 1.462993	Domain Loss: 1.627487	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 1 [6667/60000 (12%)]	Class Loss: 1.507202	Domain Loss: 1.627505	Class Accuracy: 56/59 (95%)	Domain Accuracy: 59/118 (50%)
# Train Epoch: 2 [0/60000 (0%)]	Class Loss: 1.492993	Domain Loss: 1.627300	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [64/60000 (0%)]	Class Loss: 1.473865	Domain Loss: 1.627430	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [128/60000 (0%)]	Class Loss: 1.479169	Domain Loss: 1.627272	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [192/60000 (0%)]	Class Loss: 1.490831	Domain Loss: 1.627216	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [256/60000 (0%)]	Class Loss: 1.518225	Domain Loss: 1.627148	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [320/60000 (1%)]	Class Loss: 1.478894	Domain Loss: 1.627261	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [384/60000 (1%)]	Class Loss: 1.505818	Domain Loss: 1.627270	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [448/60000 (1%)]	Class Loss: 1.488760	Domain Loss: 1.627208	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [512/60000 (1%)]	Class Loss: 1.508890	Domain Loss: 1.627244	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [576/60000 (1%)]	Class Loss: 1.503400	Domain Loss: 1.627238	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [640/60000 (1%)]	Class Loss: 1.503010	Domain Loss: 1.627213	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [704/60000 (1%)]	Class Loss: 1.485692	Domain Loss: 1.627222	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [768/60000 (1%)]	Class Loss: 1.490453	Domain Loss: 1.627178	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [832/60000 (1%)]	Class Loss: 1.494638	Domain Loss: 1.627141	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [896/60000 (1%)]	Class Loss: 1.536213	Domain Loss: 1.627091	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [960/60000 (2%)]	Class Loss: 1.507775	Domain Loss: 1.627178	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1024/60000 (2%)]	Class Loss: 1.509785	Domain Loss: 1.627178	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1088/60000 (2%)]	Class Loss: 1.517993	Domain Loss: 1.627114	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1152/60000 (2%)]	Class Loss: 1.558453	Domain Loss: 1.627160	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1216/60000 (2%)]	Class Loss: 1.486248	Domain Loss: 1.627137	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1280/60000 (2%)]	Class Loss: 1.475723	Domain Loss: 1.627181	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1344/60000 (2%)]	Class Loss: 1.529492	Domain Loss: 1.627161	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1408/60000 (2%)]	Class Loss: 1.490837	Domain Loss: 1.627166	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1472/60000 (2%)]	Class Loss: 1.481283	Domain Loss: 1.627186	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1536/60000 (3%)]	Class Loss: 1.541321	Domain Loss: 1.627147	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1600/60000 (3%)]	Class Loss: 1.513451	Domain Loss: 1.627165	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1664/60000 (3%)]	Class Loss: 1.488119	Domain Loss: 1.627145	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1728/60000 (3%)]	Class Loss: 1.469242	Domain Loss: 1.627163	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1792/60000 (3%)]	Class Loss: 1.488944	Domain Loss: 1.627150	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1856/60000 (3%)]	Class Loss: 1.496477	Domain Loss: 1.627119	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1920/60000 (3%)]	Class Loss: 1.474338	Domain Loss: 1.627136	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [1984/60000 (3%)]	Class Loss: 1.461265	Domain Loss: 1.627127	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2048/60000 (3%)]	Class Loss: 1.484141	Domain Loss: 1.627125	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2112/60000 (4%)]	Class Loss: 1.465732	Domain Loss: 1.627105	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2176/60000 (4%)]	Class Loss: 1.539316	Domain Loss: 1.627108	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2240/60000 (4%)]	Class Loss: 1.489380	Domain Loss: 1.627095	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2304/60000 (4%)]	Class Loss: 1.509143	Domain Loss: 1.627078	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2368/60000 (4%)]	Class Loss: 1.462310	Domain Loss: 1.627100	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2432/60000 (4%)]	Class Loss: 1.517094	Domain Loss: 1.627071	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2496/60000 (4%)]	Class Loss: 1.523665	Domain Loss: 1.627083	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2560/60000 (4%)]	Class Loss: 1.499125	Domain Loss: 1.627054	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2624/60000 (4%)]	Class Loss: 1.504990	Domain Loss: 1.626717	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2688/60000 (4%)]	Class Loss: 1.476880	Domain Loss: 1.627019	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2752/60000 (5%)]	Class Loss: 1.474631	Domain Loss: 1.626972	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2816/60000 (5%)]	Class Loss: 1.525506	Domain Loss: 1.627001	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2880/60000 (5%)]	Class Loss: 1.466913	Domain Loss: 1.626762	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [2944/60000 (5%)]	Class Loss: 1.534044	Domain Loss: 1.627008	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3008/60000 (5%)]	Class Loss: 1.499550	Domain Loss: 1.627005	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3072/60000 (5%)]	Class Loss: 1.512004	Domain Loss: 1.626985	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3136/60000 (5%)]	Class Loss: 1.538301	Domain Loss: 1.627047	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3200/60000 (5%)]	Class Loss: 1.461965	Domain Loss: 1.627055	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3264/60000 (5%)]	Class Loss: 1.501579	Domain Loss: 1.627036	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3328/60000 (6%)]	Class Loss: 1.494422	Domain Loss: 1.627038	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3392/60000 (6%)]	Class Loss: 1.521645	Domain Loss: 1.627001	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3456/60000 (6%)]	Class Loss: 1.520064	Domain Loss: 1.627033	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3520/60000 (6%)]	Class Loss: 1.514630	Domain Loss: 1.626978	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3584/60000 (6%)]	Class Loss: 1.504992	Domain Loss: 1.626965	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3648/60000 (6%)]	Class Loss: 1.498943	Domain Loss: 1.626979	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3712/60000 (6%)]	Class Loss: 1.463628	Domain Loss: 1.626959	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3776/60000 (6%)]	Class Loss: 1.503256	Domain Loss: 1.626960	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3840/60000 (6%)]	Class Loss: 1.496359	Domain Loss: 1.627015	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3904/60000 (7%)]	Class Loss: 1.478357	Domain Loss: 1.627022	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [3968/60000 (7%)]	Class Loss: 1.486270	Domain Loss: 1.626970	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4032/60000 (7%)]	Class Loss: 1.527587	Domain Loss: 1.626919	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4096/60000 (7%)]	Class Loss: 1.490767	Domain Loss: 1.626960	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4160/60000 (7%)]	Class Loss: 1.496266	Domain Loss: 1.626939	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4224/60000 (7%)]	Class Loss: 1.494362	Domain Loss: 1.626954	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4288/60000 (7%)]	Class Loss: 1.498554	Domain Loss: 1.626940	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4352/60000 (7%)]	Class Loss: 1.518890	Domain Loss: 1.626876	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4416/60000 (7%)]	Class Loss: 1.467804	Domain Loss: 1.626843	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4480/60000 (7%)]	Class Loss: 1.514274	Domain Loss: 1.626890	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4544/60000 (8%)]	Class Loss: 1.484602	Domain Loss: 1.626932	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4608/60000 (8%)]	Class Loss: 1.505517	Domain Loss: 1.626899	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4672/60000 (8%)]	Class Loss: 1.513576	Domain Loss: 1.626891	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4736/60000 (8%)]	Class Loss: 1.498237	Domain Loss: 1.626981	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4800/60000 (8%)]	Class Loss: 1.500703	Domain Loss: 1.626935	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4864/60000 (8%)]	Class Loss: 1.503746	Domain Loss: 1.626955	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4928/60000 (8%)]	Class Loss: 1.515813	Domain Loss: 1.626952	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [4992/60000 (8%)]	Class Loss: 1.511470	Domain Loss: 1.626916	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5056/60000 (8%)]	Class Loss: 1.474568	Domain Loss: 1.626902	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5120/60000 (9%)]	Class Loss: 1.521602	Domain Loss: 1.626903	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5184/60000 (9%)]	Class Loss: 1.531500	Domain Loss: 1.626860	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5248/60000 (9%)]	Class Loss: 1.500096	Domain Loss: 1.626871	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5312/60000 (9%)]	Class Loss: 1.521553	Domain Loss: 1.626920	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5376/60000 (9%)]	Class Loss: 1.481764	Domain Loss: 1.626860	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5440/60000 (9%)]	Class Loss: 1.505067	Domain Loss: 1.626929	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5504/60000 (9%)]	Class Loss: 1.516610	Domain Loss: 1.626842	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5568/60000 (9%)]	Class Loss: 1.496778	Domain Loss: 1.626756	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5632/60000 (9%)]	Class Loss: 1.493301	Domain Loss: 1.626811	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5696/60000 (9%)]	Class Loss: 1.507619	Domain Loss: 1.626857	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5760/60000 (10%)]	Class Loss: 1.505434	Domain Loss: 1.626860	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5824/60000 (10%)]	Class Loss: 1.493602	Domain Loss: 1.626889	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5888/60000 (10%)]	Class Loss: 1.498276	Domain Loss: 1.626853	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [5952/60000 (10%)]	Class Loss: 1.505137	Domain Loss: 1.626867	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6016/60000 (10%)]	Class Loss: 1.488260	Domain Loss: 1.626890	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6080/60000 (10%)]	Class Loss: 1.493029	Domain Loss: 1.626892	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6144/60000 (10%)]	Class Loss: 1.493963	Domain Loss: 1.626834	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6208/60000 (10%)]	Class Loss: 1.461745	Domain Loss: 1.626883	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6272/60000 (10%)]	Class Loss: 1.500449	Domain Loss: 1.626900	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6336/60000 (11%)]	Class Loss: 1.492956	Domain Loss: 1.626876	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6400/60000 (11%)]	Class Loss: 1.481834	Domain Loss: 1.626875	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6464/60000 (11%)]	Class Loss: 1.525502	Domain Loss: 1.626697	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6528/60000 (11%)]	Class Loss: 1.507759	Domain Loss: 1.626806	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6592/60000 (11%)]	Class Loss: 1.477068	Domain Loss: 1.626839	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6656/60000 (11%)]	Class Loss: 1.560458	Domain Loss: 1.626883	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6720/60000 (11%)]	Class Loss: 1.519596	Domain Loss: 1.626899	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6784/60000 (11%)]	Class Loss: 1.484622	Domain Loss: 1.626893	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6848/60000 (11%)]	Class Loss: 1.524528	Domain Loss: 1.626896	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6912/60000 (12%)]	Class Loss: 1.490278	Domain Loss: 1.626886	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6976/60000 (12%)]	Class Loss: 1.480775	Domain Loss: 1.626889	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [7040/60000 (12%)]	Class Loss: 1.479086	Domain Loss: 1.626870	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [7104/60000 (12%)]	Class Loss: 1.467300	Domain Loss: 1.626870	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [7168/60000 (12%)]	Class Loss: 1.501216	Domain Loss: 1.626847	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 2 [6667/60000 (12%)]	Class Loss: 1.512503	Domain Loss: 1.626892	Class Accuracy: 56/59 (95%)	Domain Accuracy: 59/118 (50%)
# Train Epoch: 3 [0/60000 (0%)]	Class Loss: 1.463290	Domain Loss: 1.626890	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [64/60000 (0%)]	Class Loss: 1.536343	Domain Loss: 1.626842	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [128/60000 (0%)]	Class Loss: 1.519780	Domain Loss: 1.626898	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [192/60000 (0%)]	Class Loss: 1.488035	Domain Loss: 1.626885	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [256/60000 (0%)]	Class Loss: 1.464069	Domain Loss: 1.626871	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [320/60000 (1%)]	Class Loss: 1.471610	Domain Loss: 1.626859	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [384/60000 (1%)]	Class Loss: 1.477002	Domain Loss: 1.626880	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [448/60000 (1%)]	Class Loss: 1.487828	Domain Loss: 1.626882	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [512/60000 (1%)]	Class Loss: 1.489049	Domain Loss: 1.626865	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [576/60000 (1%)]	Class Loss: 1.487575	Domain Loss: 1.626875	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [640/60000 (1%)]	Class Loss: 1.477513	Domain Loss: 1.626863	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [704/60000 (1%)]	Class Loss: 1.481468	Domain Loss: 1.626874	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 3 [768/60000 (1%)]	Class Loss: 1.484446	Domain Loss: 1.626876	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# ...
# Train Epoch: 8 [7040/60000 (12%)]	Class Loss: 1.497802	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 8 [7104/60000 (12%)]	Class Loss: 1.465619	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 8 [7168/60000 (12%)]	Class Loss: 1.481054	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 8 [6667/60000 (12%)]	Class Loss: 1.492239	Domain Loss: 1.626523	Class Accuracy: 57/59 (97%)	Domain Accuracy: 59/118 (50%)
# Train Epoch: 9 [0/60000 (0%)]	Class Loss: 1.478039	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [64/60000 (0%)]	Class Loss: 1.496324	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [128/60000 (0%)]	Class Loss: 1.560250	Domain Loss: 1.626524	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [192/60000 (0%)]	Class Loss: 1.493732	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [256/60000 (0%)]	Class Loss: 1.484591	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [320/60000 (1%)]	Class Loss: 1.479048	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [384/60000 (1%)]	Class Loss: 1.461334	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [448/60000 (1%)]	Class Loss: 1.473982	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [512/60000 (1%)]	Class Loss: 1.497074	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [576/60000 (1%)]	Class Loss: 1.481958	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [640/60000 (1%)]	Class Loss: 1.487691	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [704/60000 (1%)]	Class Loss: 1.489524	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [768/60000 (1%)]	Class Loss: 1.512991	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [832/60000 (1%)]	Class Loss: 1.495237	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [896/60000 (1%)]	Class Loss: 1.477404	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [960/60000 (2%)]	Class Loss: 1.476833	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1024/60000 (2%)]	Class Loss: 1.485665	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1088/60000 (2%)]	Class Loss: 1.478680	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1152/60000 (2%)]	Class Loss: 1.477482	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1216/60000 (2%)]	Class Loss: 1.461295	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1280/60000 (2%)]	Class Loss: 1.462651	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1344/60000 (2%)]	Class Loss: 1.462517	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1408/60000 (2%)]	Class Loss: 1.496336	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1472/60000 (2%)]	Class Loss: 1.461426	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1536/60000 (3%)]	Class Loss: 1.461270	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1600/60000 (3%)]	Class Loss: 1.487744	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1664/60000 (3%)]	Class Loss: 1.484982	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1728/60000 (3%)]	Class Loss: 1.483658	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1792/60000 (3%)]	Class Loss: 1.461187	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1856/60000 (3%)]	Class Loss: 1.545966	Domain Loss: 1.626524	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1920/60000 (3%)]	Class Loss: 1.508459	Domain Loss: 1.626524	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [1984/60000 (3%)]	Class Loss: 1.473726	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2048/60000 (3%)]	Class Loss: 1.484113	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2112/60000 (4%)]	Class Loss: 1.462163	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2176/60000 (4%)]	Class Loss: 1.509479	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2240/60000 (4%)]	Class Loss: 1.482127	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2304/60000 (4%)]	Class Loss: 1.475889	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2368/60000 (4%)]	Class Loss: 1.509228	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2432/60000 (4%)]	Class Loss: 1.508634	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2496/60000 (4%)]	Class Loss: 1.490471	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2560/60000 (4%)]	Class Loss: 1.503368	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2624/60000 (4%)]	Class Loss: 1.493855	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2688/60000 (4%)]	Class Loss: 1.488964	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2752/60000 (5%)]	Class Loss: 1.506921	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2816/60000 (5%)]	Class Loss: 1.507766	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2880/60000 (5%)]	Class Loss: 1.483239	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [2944/60000 (5%)]	Class Loss: 1.477043	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3008/60000 (5%)]	Class Loss: 1.497762	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3072/60000 (5%)]	Class Loss: 1.511957	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3136/60000 (5%)]	Class Loss: 1.488065	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3200/60000 (5%)]	Class Loss: 1.492700	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3264/60000 (5%)]	Class Loss: 1.484063	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3328/60000 (6%)]	Class Loss: 1.488402	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3392/60000 (6%)]	Class Loss: 1.478221	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3456/60000 (6%)]	Class Loss: 1.483046	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3520/60000 (6%)]	Class Loss: 1.465792	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3584/60000 (6%)]	Class Loss: 1.478724	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3648/60000 (6%)]	Class Loss: 1.476786	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3712/60000 (6%)]	Class Loss: 1.477364	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3776/60000 (6%)]	Class Loss: 1.465835	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3840/60000 (6%)]	Class Loss: 1.461345	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3904/60000 (7%)]	Class Loss: 1.483679	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [3968/60000 (7%)]	Class Loss: 1.462291	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4032/60000 (7%)]	Class Loss: 1.475257	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4096/60000 (7%)]	Class Loss: 1.476756	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4160/60000 (7%)]	Class Loss: 1.490696	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4224/60000 (7%)]	Class Loss: 1.479708	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4288/60000 (7%)]	Class Loss: 1.469785	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4352/60000 (7%)]	Class Loss: 1.465031	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4416/60000 (7%)]	Class Loss: 1.475841	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4480/60000 (7%)]	Class Loss: 1.476965	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4544/60000 (8%)]	Class Loss: 1.476636	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4608/60000 (8%)]	Class Loss: 1.512577	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4672/60000 (8%)]	Class Loss: 1.470705	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4736/60000 (8%)]	Class Loss: 1.483716	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4800/60000 (8%)]	Class Loss: 1.475731	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4864/60000 (8%)]	Class Loss: 1.496142	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4928/60000 (8%)]	Class Loss: 1.508476	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [4992/60000 (8%)]	Class Loss: 1.496422	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5056/60000 (8%)]	Class Loss: 1.490081	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5120/60000 (9%)]	Class Loss: 1.492343	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5184/60000 (9%)]	Class Loss: 1.492542	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5248/60000 (9%)]	Class Loss: 1.477087	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5312/60000 (9%)]	Class Loss: 1.465928	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5376/60000 (9%)]	Class Loss: 1.492694	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5440/60000 (9%)]	Class Loss: 1.526207	Domain Loss: 1.626524	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5504/60000 (9%)]	Class Loss: 1.516334	Domain Loss: 1.626524	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5568/60000 (9%)]	Class Loss: 1.466123	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5632/60000 (9%)]	Class Loss: 1.466451	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5696/60000 (9%)]	Class Loss: 1.474802	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5760/60000 (10%)]	Class Loss: 1.470815	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5824/60000 (10%)]	Class Loss: 1.496334	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5888/60000 (10%)]	Class Loss: 1.508880	Domain Loss: 1.626524	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [5952/60000 (10%)]	Class Loss: 1.494748	Domain Loss: 1.626524	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6016/60000 (10%)]	Class Loss: 1.477008	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6080/60000 (10%)]	Class Loss: 1.481959	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6144/60000 (10%)]	Class Loss: 1.473991	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6208/60000 (10%)]	Class Loss: 1.527129	Domain Loss: 1.626524	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6272/60000 (10%)]	Class Loss: 1.472428	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6336/60000 (11%)]	Class Loss: 1.484800	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6400/60000 (11%)]	Class Loss: 1.486438	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6464/60000 (11%)]	Class Loss: 1.476976	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6528/60000 (11%)]	Class Loss: 1.481955	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6592/60000 (11%)]	Class Loss: 1.476779	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6656/60000 (11%)]	Class Loss: 1.503704	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6720/60000 (11%)]	Class Loss: 1.479623	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6784/60000 (11%)]	Class Loss: 1.476959	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6848/60000 (11%)]	Class Loss: 1.475949	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6912/60000 (12%)]	Class Loss: 1.476924	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6976/60000 (12%)]	Class Loss: 1.481035	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [7040/60000 (12%)]	Class Loss: 1.508253	Domain Loss: 1.626524	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [7104/60000 (12%)]	Class Loss: 1.476826	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [7168/60000 (12%)]	Class Loss: 1.462011	Domain Loss: 1.626524	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 9 [6667/60000 (12%)]	Class Loss: 1.461651	Domain Loss: 1.626523	Class Accuracy: 59/59 (100%)	Domain Accuracy: 59/118 (50%)
# Train Accuracy Class Classifier: 68605/72910 (94%)
# Train Accuracy Domain Classifier: 72625/145820 (50%)
# Best Accuracy: 50% at Epoch: 9

# %% [markdown]
# ## Testing

# %%
#test DANN on the test data
DANN_test(feature_extractor, class_classifier, domain_classifier, test_loader, dataset='TARGET')
# Out:
# /tmp/ipykernel_29758/1062286346.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# /tmp/ipykernel_29758/2842852021.py:33: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# TARGET_Test Accuracy Class Classifier: 6696/7291 (92%)
# TARGET_Test Accuracy Domain Classifier: 7291/7291 (100%)

# %%
#test  DANN predictions on train data
DANN_test(feature_extractor, class_classifier, domain_classifier, train_loader, dataset='SOURCE')
# Out:
# /tmp/ipykernel_29758/1062286346.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# /tmp/ipykernel_29758/2842852021.py:33: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# SOURCE_Test Accuracy Class Classifier: 58527/60000 (98%)
# SOURCE_Test Accuracy Domain Classifier: 0/60000 (0%)
