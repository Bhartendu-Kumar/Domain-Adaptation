# %%
#the dataset we will use is MNIST and USPS

#In this notebook we will implement the domain adversarial training of neural network

#the code is based on the paper "Domain-Adversarial Training of Neural Networks"
#also the architecture is same as the paper "Unsupervised Domain Adaptation by Backpropagation"

# %%
#we will use resnet50 as the base network
# we will use gradient reversal layer to implement the domain adversarial training
#we will implement gradient reversal layer at three different stages of the base
# classifier.

# %%
#first we will try to implement the gradient reversal layer at the end of the base classifier i.e. just before the fully connected layer and after the last feature extractor layer

# %%
experiment_name = 'mnist_dann'
version = 'v0'

#concat experiment name and version to get experiment id
experiment_id = experiment_name + '_' + version

model_path = 'saved_models/DANN'

# %%
#GPU name
#
GPU_NAME = 'cuda:0'

# %%
#neceassary imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable, Function
# from torchvision import datasets, transforms
from torch.utils.data import DataLoader, SubsetRandomSampler
import torch.utils.data as data
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torchvision.models as models
import torch.backends.cudnn as cudnn

import numpy as np

#import utils
import os
import itertools
import time
import copy
import random
import math

# %%
#imports for visualizations
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
from torchvision.models import resnet50, ResNet50_Weights
from torchvision.io import read_image
from torchsummary import summary
#import tenserboard
from torch.utils.tensorboard import SummaryWriter

# %%
#enable cudnn
cudnn.benchmark = True
#cuda cache clear
torch.cuda.empty_cache()

#set random seed
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %%
#device
device = torch.device(GPU_NAME if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
#defining the hyperparameters
BATCH = 64

EPOCHS = 1
IMAGE_SIZE = 224
CHANNELS_IMG = 1
NUM_CLASSES = 10


C = 1   #weight of the domain loss
LAMBDA = 1 #scaling factor for the gradient reversal layer
GAMMA = 10

#parameters of ADAM optimizer
LEARNING_RATE = 0.001
BETA_1 = 0.9
BETA_2 = 0.999

#parameters of SGD optimizer with momentum
MOMENTUM = 0.9

# %% [markdown]
# # Utility functions

# %%
#define function to get one hot encoding of labels
def one_hot_encoding(label, total_classes=NUM_CLASSES):
    vect = torch.eye(total_classes)
    return vect[label]

# %%
#we will define optimizer scheduler

# %% [markdown]
# ## Model

# %%
## we will build 3 different models for implementing the domain adversarial training
#first be the feature extractor drived from resnet50
#second be a classifier after the feature extractor layer of resnet50
#third be the domain classifier with input as the feature vector from the feature extractor and output as the domain label

# %% [markdown]
# #### Base resnet50

# %%
#let us first build the feature extractor
#we input a resent50 model

#creating the model
weights = ResNet50_Weights.DEFAULT
#send weight sto gpu
# weights = weights.to(device)
#sending the model to GPU

base_resnet = resnet50(weights=weights).to(device)

# %%
#print model
base_resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
#we will change the first convolution layer to accept single channel image
#conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
# #if CHANNELS_IMG == 1:
# if CHANNELS_IMG == 1:
#     base_resnet.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)

# #change the last fully connected layer to output classes in NUM_CLASSES
# base_resnet.fc = nn.Linear(2048, NUM_CLASSES,  bias=True)

#write a function to changethe model based on number of channels and number of classes
def change_model(model, num_channels = CHANNELS_IMG, num_classes = NUM_CLASSES):
    if num_channels == 1:
        model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
    
    model.fc = nn.Linear(2048, num_classes,  bias=True)
    return model


base_resnet = change_model(base_resnet, num_channels = CHANNELS_IMG, num_classes = NUM_CLASSES)
base_resnet
# Out:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %%
#now we will write class for the feature extractor network
#we will pass the resnet50 model as the input to the class, and will use : nn.Sequential(*list(original_model.children())[:-2]) to get the feature extractor part of the model

class FeatureExtractor(nn.Module):
    def __init__(self, base_model):
        super(FeatureExtractor, self).__init__()
        # self.base_model = base_model
        self.feature_extractor = nn.Sequential(*list(base_model.children())[:-2])

    def forward(self, x):
        x = self.feature_extractor(x)
        return x

# %%
#now create an instance of the feature extractor and print the model
feature_extractor = FeatureExtractor(base_resnet).to(device)
feature_extractor
# Out:
# FeatureExtractor(
#   (feature_extractor): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
# )

# %%
#print summary of the model
summary(feature_extractor, (1, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           3,136
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# ================================================================
# Total params: 23,501,760
# Trainable params: 23,501,760
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 286.54
# Params size (MB): 89.65
# Estimated Total Size (MB): 376.38
# ----------------------------------------------------------------

# %%
# #create a random tensor and pass it through the feature extractor
# x = torch.randn(1, 1, 224, 224).to(device)
# out_feature_extractor = feature_extractor(x)
# out_feature_extractor.shape

# %%
# #now we will create the classifier, it will be same as the part of the resnet50 model after the feature extractor i.e. the last two layers of the resnet50 model
# #also the number of classes will be 10 as we have 10 classes in the MNIST dataset, the number of classes is stored in NUM_CLASSES

# class ClassClassifier(nn.Module):
#     def __init__(self, base_model, num_classes=NUM_CLASSES):
#         super(ClassClassifier, self).__init__()
#         self.num_classes = num_classes
#         self.classifier = nn.Sequential(*list(base_model.children())[-2:])

#     def forward(self, x):
#         #print the shape of the input
#         print("inside classifier: input shape",x.shape)
#         x = self.classifier(x)
#         # x = x.view(-1, self.num_classes)
#         return F.softmax(x)

# %%
#now we will create the classifier, it will be same as the part of the resnet50 model after the feature extractor i.e. the last two layers of the resnet50 model
#also the number of classes will be 10 as we have 10 classes in the MNIST dataset, the number of classes is stored in NUM_CLASSES

class ClassClassifier(nn.Module):
    def __init__(self, base_model):
        super(ClassClassifier, self).__init__()
        self.avgpool= nn.Sequential(*list(base_model.children())[-2:-1])
        self.flatten = nn.Flatten()
        self.fc = nn.Sequential(*list(base_model.children())[-1:])
        #define a flatten layer
        

    def forward(self, x):
        #print the shape of the input
        # print("inside classifier: input shape",x.shape)
        x = self.avgpool(x)

        x = self.flatten(x)

        x = self.fc(x)
        return F.softmax(x)

# %%
#create an instance of the classifier and print the model
class_classifier = ClassClassifier(base_resnet).to(device)
class_classifier
# Out:
# ClassClassifier(
#   (avgpool): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=10, bias=True)
#   )
# )

# %%
# print summary of the model
summary(class_classifier, (2048, 1, 1))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#  AdaptiveAvgPool2d-1           [-1, 2048, 1, 1]               0
#            Flatten-2                 [-1, 2048]               0
#             Linear-3                   [-1, 10]          20,490
# ================================================================
# Total params: 20,490
# Trainable params: 20,490
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.03
# Params size (MB): 0.08
# Estimated Total Size (MB): 0.12
# ----------------------------------------------------------------
# /tmp/ipykernel_324708/1062286346.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)

# %%
# #pass the out_feature_extractor through the classifier
# out_classifier = classifier(out_feature_extractor)
# #print the shape of the output
# print("output shape", out_classifier.shape)
# # out_classifier.shape
# #print the output of the classifier
# print("output", out_classifier)

# %%
# # summary of the classifier
# #create 
# summary(classifier, (2048, 1, 1))

# %%
#let us write gradient reversal layer

class GradientReversalLayer(Function):
    @staticmethod
    def forward(ctx, x, lambda_):
        ctx.lambda_ = lambda_
        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.lambda_
        return output, None
    
    def grad_reverse(x, lambda_):
        return GradientReversalLayer.apply(x, lambda_)

# %%
#now we will create the domain classifier: named as DomainClassifier
#it will have the rest of the resnet model after the feature extractor and the classifier and will have an additional layer at the end to output the domain label: 0 for source and 1 for target
#it will have gradient reversal layer in between the feature extractor and the classifier, i.e the first layer of the domain classifier 
#it will be exactly same as ClassClassifier except for the last layer, which is not number of classes but 2 for domain labels and sigmoid activation function instead of softmax
#it will also do same [-2:] to get the classifier part of the model, first layer be gradient reversal layer

class DomainClassifier(nn.Module):
    def __init__(self, base_model):
        super(DomainClassifier, self).__init__()
        #first layer of the domain classifier be the gradient reversal layer

        self.avgpool = nn.Sequential(*list(base_model.children())[-2:-1])
        self.flatten = nn.Flatten()
        self.fc = nn.Sequential(nn.Linear(2048, 2, bias=True))
        
        #now add the last output layer
        # self.domain_classifier.add_module('domain_classifier_output', nn.Linear(2048, 2))
        #change the last layer to output 2 classes
        # self.fc = nn.Linear(2048, 2 , bias=True)

        #forward
    def forward(self, x, lambda_ = LAMBDA):
        x = GradientReversalLayer.grad_reverse(x, lambda_)
        x = self.avgpool(x)
        x = self.flatten(x)
        #output the domain label
        x = self.fc(x)
        
        # x = x.view(-1, 2)
        return F.softmax(x)

# %%
#create an instance of the domain classifier and print the model
domain_classifier = DomainClassifier(base_resnet).to(device)
domain_classifier
# Out:
# DomainClassifier(
#   (avgpool): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=2, bias=True)
#   )
# )

# %%
#print summary of the model
summary(domain_classifier, (2048, 1, 1))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#  AdaptiveAvgPool2d-1           [-1, 2048, 1, 1]               0
#            Flatten-2                 [-1, 2048]               0
#             Linear-3                    [-1, 2]           4,098
# ================================================================
# Total params: 4,098
# Trainable params: 4,098
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.03
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.05
# ----------------------------------------------------------------
# /tmp/ipykernel_324708/3753341005.py:29: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)

# %%
# #create an instance of the domain classifier and print the model
# domain_classifier = DomainClassifier(base_resnet).to(device)
# #pass the output of feature extractor through the domain classifier
# out_domain_classifier = domain_classifier(out_feature_extractor, 1)
# #print the shape of the output
# print("output shape", out_domain_classifier.shape)
# #print the output of the domain classifier
# print("output", out_domain_classifier)

# %% [markdown]
# ## Data-Processing

# %%
preprocess = weights.transforms()

# %%
#define the transform for the dataset
transform_mnist_resnet = transforms.Compose(
    [
  
    # if torch tensor then leave as it is, else convert to tensor
    transforms.Lambda(lambda x: x if isinstance(x, torch.Tensor) else transforms.functional.to_tensor(x)),
    #

    #resize to 224x224
    transforms.Resize(IMAGE_SIZE),

    #check if channels are 1, then convert to 3 channels
    transforms.Lambda(lambda x: x.repeat(3, 1, 1) if x.shape[0] == 1 else x),

    transforms.Lambda(lambda x: preprocess(x)),

    #if channels are 3, then make them 1
    transforms.Lambda(lambda x: x[0].unsqueeze(0) if x.shape[0] == 3 else x),
    
    # normalize
    transforms.Normalize(
            [0.5 for _ in range(CHANNELS_IMG)], [0.5 for _ in range(CHANNELS_IMG)]
        ),
    ]
)

# %% [markdown]
# #### Dataset

# %%
# for training we will use MNIST dataset in pytorch library
#for testing we will use USPS dataset

# %% [markdown]
# #### train data - MNIST
# #### test data - USPS

# %%
#load train data
train_data = datasets.MNIST(root='./data/', download=True, transform=transform_mnist_resnet) 
#load train data
train_loader = torch.utils.data.DataLoader(train_data, batch_size=BATCH, shuffle=True, num_workers=4)

# %%
#load test data
#USPS dataset
test_data = datasets.USPS(root='./data/', download=True, transform=transform_mnist_resnet)
#load test data
test_loader = torch.utils.data.DataLoader(test_data, batch_size=BATCH, shuffle=True, num_workers=4)

# %%
#print the length of train and test data
print(len(train_data))
#print the shape of train data
print(train_data[0][0].shape)
# Out:
# 60000
# torch.Size([1, 224, 224])

# %%
#print length of test data
print(len(test_data))
#print shape of test data
print(test_data[0][0].shape)
# Out:
# 7291
# torch.Size([1, 224, 224])

# %%
#print number of batches in train and test data
print(len(train_loader))
print(len(test_loader))
# Out:
# 938
# 114

# %%
# #we will test the model on the first batch of the train data, to test the dimensions of the output of the model and the loss function
# #we define a function to test the model
# def test_model(feature_extractor, class_classifier, loss_function):
#     #make the model sequential to pass the input through the feature extractor and then the output of feature extractor to the class classifier
#     # model = nn.Sequential(feature_extractor, class_classifier, loss_function)

#     #set model to eval mode
#     feature_extractor.eval()
#     class_classifier.eval()

#     #initialize the loss and number of correct predictions
#     loss = 0
#     correct = 0

#     #get the first batch of the train data
#     #wee use for and then break to get the first batch
#     for data, label in train_loader:

#         #print data shape
#         print("data shape", data.shape)
#         #print label shape
#         print("label shape", label.shape)
#         #print data type
#         print("data type", data.dtype)
#         #print label type
#         print("label type", label.dtype)
#         #print first label
#         print("first label", label[0])
#         #print all label
#         print("all label", label)


#         #move data and label to device
#         data, label = data.to(device), label.to(device)

#         #we measure the accuracy here
#         #get output from the model
#         # output = model(data)
#         #get the output from the feature extractor
#         feature = feature_extractor(data)
#         #print the shape of the feature
#         print("feature shape: ", feature.shape)
#         #print type of feature
#         print("feature type: ", type(feature))
#         #get the output from the class classifier
#         output = class_classifier(feature)
#         #print the shape of the output
#         print("output shape: ", output.shape)
#         #print type of output

#         #print output shape
#         print("output shape: ", output.shape)
#         #print output type
#         print("output type: ", type(output))

#         #get the loss
#         loss = loss_function(output, label)

#         #print loss
#         print("loss: ", loss)

#         #get the prediction
#         pred = output.argmax(dim=1, keepdim=True)
#         #print pred
#         print("pred: ", pred)
#         #update the correct predictions
#         correct = pred.eq(label.view_as(pred)).sum().item()

#         #print correct
#         print("correct: ", correct)
#         #accuracy
#         accuracy = correct / len(data)
#         #print accuracy
#         print("accuracy: ", accuracy)





#         #break
#         break

# #now we test the above function and build model and loss function
# #build the model
# #the classifier is composed of two models - feature extractor and classifier in sequence: input first passes through feature extractor and then the output of feature extractor is passed to classifier
# # and the output of classifier is the final output
# classifier = ClassClassifier(base_resnet, NUM_CLASSES).to(device)
# #build the feature extractor model from the class FeatureExtractor
# feature_extractor = FeatureExtractor(base_resnet).to(device)
# #now we make end to end model by combining the feature extractor and classifier
# # model = nn.Sequential(feature_extractor, classifier).to(device)
# #build the loss function
# loss_function = nn.CrossEntropyLoss().to(device)
# #test the model
# test_model(feature_extractor, classifier, loss_function)

# %%
#initialize tensorboard writer
#create writer for tensorboard
writer = SummaryWriter(f'runs/'+experiment_id)
# Out:
# 2022-11-08 14:55:47.542682: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
#write a save model function
#the arguments are the models, the optimizer, the epoch number, the model name
def save_model(feature_extractor, class_classifier, optimizer, epoch):
    #check if path exists, if not then create it
    #recursively check if each root directory exists, if not then recursively create each
    if not os.path.exists(model_path):
        os.makedirs(model_path)



    #we will save the model by the name of the experiment id and the epoch number
    torch.save(feature_extractor.state_dict(), f'{model_path}/{experiment_id}_feature_extractor_{epoch}.pth')
    torch.save(class_classifier.state_dict(), f'{model_path}/{experiment_id}_class_classifier_{epoch}.pth')
    torch.save(domain_classifier.state_dict(), f'{model_path}/{experiment_id}_domain_classifier_{epoch}.pth')

# %% [markdown]
# ## DANN Training

# %% [markdown]
# #### Test function

# %%
#write a function to test the model, i.e. the class classifier on the test data
#the function takes as argument : the feature extractor, class classifier, domain classifier, test data loader 
def DANN_test(feature_extractor, class_classifier, domain_classifier, test_data_loader, dataset='TARGET'):
    #set the model to evaluation mode
    feature_extractor.eval()
    class_classifier.eval()
    domain_classifier.eval()

    #set the total and correct for class classifier to 0
    total_class_classifier = 0
    correct_class_classifier = 0
    #set the total and correct for domain classifier to 0
    total_domain_classifier = 0
    correct_domain_classifier = 0
    
    #set the writer
    # writer.add_scalar
 
    #loop through the test data loader
    with torch.no_grad():
        #loop through the test data loader
        for data, labels in test_data_loader:
            #get the data and labels
            data, labels = data.to(device), labels.to(device)
            #if dataset is target, then we will add the domain labels as 1
            if dataset == 'TARGET':
                domain_labels = torch.ones(data.size(0)).long().to(device)
            #if dataset is source, then we will add the domain labels as 0
            elif dataset == 'SOURCE':
                domain_labels = torch.zeros(data.size(0)).long().to(device)
                #if dataset is not source or target, then we will raise an error
            else:
                raise ValueError('Dataset must be source or target')
            #get the feature vector
            feature_vector = feature_extractor(data)
            #get the class classifier prediction
            class_classifier_pred = class_classifier(feature_vector)
            #get the domain classifier prediction
            domain_classifier_pred = domain_classifier(feature_vector)
   
            #get the predicted class
            _, predicted_class = torch.max(class_classifier_pred.data, 1)
            #get the total and correct for class classifier
            total_class_classifier += labels.size(0)
            correct_class_classifier += (predicted_class == labels).sum().item()
            #get the total and correct for domain classifier
            _, predicted_domain = torch.max(domain_classifier_pred.data, 1)
            total_domain_classifier += domain_labels.size(0)
            correct_domain_classifier += (predicted_domain == domain_labels).sum().item()
    #print the loss and accuracy
    print(dataset+'_'+'Test Accuracy Class Classifier: {}/{} ({:.0f}%)'.format(correct_class_classifier, total_class_classifier,
        100. * correct_class_classifier / total_class_classifier))
    print(dataset+'_'+'Test Accuracy Domain Classifier: {}/{} ({:.0f}%)'.format(correct_domain_classifier, total_domain_classifier,
        100. * correct_domain_classifier / total_domain_classifier))
    
    #write the loss and accuracy to the tensorboard
    writer.add_scalar(dataset+'Test_Class_Accuracy', 100. * correct_class_classifier / total_class_classifier, global_step=0)
    writer.add_scalar(dataset+'Test_Domain_Accuracy', 100. * correct_domain_classifier / total_domain_classifier, global_step=0)
    #close the writer
    writer.close()

# %%
#let us first see the models performance on the test data before training: so we can compare the performance before and after training
#test the model on the test data
DANN_test(feature_extractor, class_classifier, domain_classifier, test_loader, dataset='TARGET')
# Out:
# /tmp/ipykernel_324708/1062286346.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# /tmp/ipykernel_324708/3753341005.py:29: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# TARGET_Test Accuracy Class Classifier: 653/7291 (9%)
# TARGET_Test Accuracy Domain Classifier: 7289/7291 (100%)

# %%
#we will also test the model on the source data
DANN_test(feature_extractor, class_classifier, domain_classifier, train_loader, dataset='SOURCE')
# Out:
# /tmp/ipykernel_324708/1062286346.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# /tmp/ipykernel_324708/3753341005.py:29: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# SOURCE_Test Accuracy Class Classifier: 5750/60000 (10%)
# SOURCE_Test Accuracy Domain Classifier: 195/60000 (0%)

# %%
# we will write a function for training the models as per DANN paper
#the arguments are: feature extractor, Class Classifier, Domain Classifier, source data loader, target data loader, number of epochs

#we will simultaneously track the loss and accuracy of the model on source and target data
#so we will store total corrects and total predictions for both source and target data


def DANN_training(feature_extractor, class_classifier, domain_classifier, source_data_loader, target_data_loader, num_epochs=EPOCHS, device = device):
    #for optimizer we will club all the parameters of all the models
    #we use Adam optimizer
    #the parameters of ADAM  are the standard ones for ADAM optimizer
    optimizer = optim.Adam(list(feature_extractor.parameters()) + list(class_classifier.parameters()) + list(domain_classifier.parameters()), lr=LEARNING_RATE, betas=(BETA_1, BETA_2))
    #we define the loss function for the domain classifier as cross entropy loss
    loss_fn_domain = nn.CrossEntropyLoss().to(device)
    #we define the loss function for the class classifier as cross entropy loss
    loss_fn_class = nn.CrossEntropyLoss().to(device)

    #we will iterate through datasets in a unique way, as we need one batch of source data and one batch of target data at a time to process through the models and then update the parameters
    #but we do not have same number of batches in source and target data
    #so we will first assume that source data has more batches than target data
    #write an assert statement to check if this is true
    assert len(source_data_loader) >= len(target_data_loader), "Source data should have more batches than target data"
    #now we have source data to have more batches than target data, thus we will have 2 loops, one for source data and one for target data
    #the outer would be for source data and inner for target data
    #and we get the batch number of the source data from the outer loop and in the inner loop through the target data we will select the corresponding batch number of the target data 
    #, if the batch number is less than or equal to the minimum of the number of batches in source and target data,
    # else when we have exhausted the target data, we will start again from the first batch of the target data
    #we will do this untill we have exhausted the source data

    #we will keep track of the batch number of the source data in the outer loop
    batch_num_source = 0
    #we will keep track of the batch number of the target data in the inner loop
    batch_num_target = 0
    #we will keep track of the minimum of the number of batches in source and target data
    min_batches = min(len(source_data_loader), len(target_data_loader))
    #we will keep track of the number of batches in source data
    num_batches_source = len(source_data_loader)
    #we will keep track of the number of batches in target data
    num_batches_target = len(target_data_loader)

    #set all the models to train mode
    feature_extractor.train()
    class_classifier.train()
    domain_classifier.train()

    #variable to store the statistics of model training, like : loss, accuracy, etc
    epoch_tracker = 0   #it tracks the loop number
    batch_tracker = 0   #it tracks the batch number * epoch number
    #loss
    # total_loss = 0
    # total_class_loss = 0
    # total_domain_loss = 0
    #accuracy
    total_class_classifier = 0
    correct_class_classifier = 0
    total_domain_classifier = 0
    correct_domain_classifier = 0

    best_epoch_accuracy = 0     #this will store the best epoch accuracy
    best_epoch = 0              #this will store the best epoch number

    #loop through the epochs
    for epoch in range(num_epochs):

        #if epoch is not 0, then we have values stored in epoch_total_class_classifier, epoch_total_class_correct, epoch_total_domain_classifier, epoch_total_domain_correct
        #so we will calculate the accuracy and loss for the previous epoch
        if epoch != 0:
            #calculate the accuracy
            epoch_accuracy_class_classifier = 100 * correct_class_classifier / total_class_classifier
            epoch_accuracy_domain_classifier = 100 * correct_domain_classifier / total_domain_classifier
            epoch_accuracy_source_domain_classifier = 100 * epoch_correct_source_domain_classifier / epoch_total_source_domain_classifier
            epoch_accuracy_target_domain_classifier = 100 * epoch_correct_target_domain_classifier / epoch_total_target_domain_classifier
            
            #calculate the loss, we divide total loss by batch_size, as we have added the loss for all the elements in the batch
            epoch_loss_class_classifier = epoch_total_class_loss /  batch_min_size
            epoch_loss_domain_classifier = epoch_total_domain_loss / batch_min_size
            epoch_total_loss = epoch_total_loss / batch_min_size
            #write the loss and accuracy to tensorboard
            writer.add_scalar('EPOCH_Train_Loss_class_classifier', epoch_loss_class_classifier, epoch_tracker)
            writer.add_scalar('EPOCH_Train_Loss_domain_classifier', epoch_loss_domain_classifier, epoch_tracker)
            #write epoch total_loss to tensorboard
            writer.add_scalar('EPOCH_Train_Loss', epoch_total_loss, epoch_tracker)
            writer.add_scalar('EPOCH_Train_Accuracy_class_classifier', epoch_accuracy_class_classifier, epoch_tracker)
            writer.add_scalar('EPOCH_Train_Accuracy_domain_classifier', epoch_accuracy_domain_classifier, epoch_tracker)
            #write accuracy of domain classifier on source data and target data to tensorboard
            writer.add_scalar('EPOCH_Train_Accuracy_domain_classifier_SOURCE', epoch_accuracy_domain_classifier_SOURCE, epoch_tracker)

            #if the epoch_accuracy_domain_classifier is greater than best_epoch_accuracy, then we will update the best_epoch_accuracy and best_epoch
            if epoch_accuracy_domain_classifier > best_epoch_accuracy:
                best_epoch_accuracy = epoch_accuracy_domain_classifier
                best_epoch = epoch
                #we will save the model by the name of the experiment id and the epoch number
                #call the save_model function
                save_model(feature_extractor, class_classifier, domain_classifier, epoch)



            #increment the epoch tracker
            epoch_tracker += 1
            
          

        #epoch variable to track statistics in an epoch
        #loss
        epoch_total_loss = 0
        epoch_total_class_loss = 0
        epoch_total_domain_loss = 0
        #accuracy
        epoch_total_class_classifier = 0
        epoch_correct_class_classifier = 0
        epoch_total_domain_classifier = 0
        epoch_correct_domain_classifier = 0
        #
        epoch_total_source_domain_classifier = 0
        epoch_correct_source_domain_classifier = 0
        epoch_total_target_domain_classifier = 0
        epoch_correct_target_domain_classifier = 0

        

        #start outer loop for source data
        for batch_idx_source, (source_data, source_labels) in enumerate(source_data_loader):
            #if the batch number of source data is less than the minimum of the number of batches in source and target data, then we will select the corresponding batch number of the target data
            #we name that as batch_of_target
            if batch_idx_source < min_batches:
                batch_of_target = batch_idx_source

            #check if the batch_idx_source is equal to or greater than the minimum of the number of batches in source and target data
            else:
                #if yes, then we will start again from the first batch of the target data
                batch_of_target = batch_idx_source % min_batches

            #start inner loop for target data
            for batch_idx_target, (target_data, target_labels) in enumerate(target_data_loader):
                
                #now we will run the inner loop only when batch_idx_target is equal to the batch_of_target
                #in all else cases we will continue
                if batch_idx_target != batch_of_target:
                    continue

                temp_total_class_classifier = 0
                temp_correct_class_classifier = 0
                temp_total_domain_classifier = 0
                temp_correct_domain_classifier = 0

                #now we have one batch of source data and one batch of target data
                #now we run as if we are training a normal model with source data and target data in a single batch
                #send source data and target data to device
                source_data, source_labels = source_data.to(device), source_labels.to(device)
                target_data, target_labels = target_data.to(device), target_labels.to(device)

                #now we will calculate the lambda for gradient reversal layer: for current loop
                p = float(batch_idx_source + epoch *num_batches_source ) / num_epochs * num_batches_source
                lambda_ = 2. / (1. + np.exp(- GAMMA * p)) - 1

                #now we check that the number of images in source data and target data are same: i.e. batch size is same: this is particularly useful in case of last batch
                batch_min_size = min(source_data.shape[0], target_data.shape[0])
                #now we will select the same number of images from source and target data
                source_data = source_data[:batch_min_size]
                source_labels = source_labels[:batch_min_size]
                target_data = target_data[:batch_min_size]
                target_labels = target_labels[:batch_min_size]


                #zero grdient optimizer
                optimizer.zero_grad()

                #now we will create the domain labels for source and target data
                #this is required for the domain classifier
                #source domain label is 0
                source_domain_labels = torch.zeros(source_data.shape[0]).long().to(device)
                #target domain label is 1
                target_domain_labels = torch.ones(target_data.shape[0]).long().to(device)

                #now we will pass the source data and target data through the feature extractor
                source_features = feature_extractor(source_data)
                target_features = feature_extractor(target_data)

                #now we will calculate class prediction of source data
                source_class_pred = class_classifier(source_features)
                #now we calculate the loss for the class classifier
                class_classifier_loss = loss_fn_class(source_class_pred, source_labels)

                #now we will calculate the domain prediction of source data and target data
                source_domain_pred = domain_classifier(source_features, lambda_)
                target_domain_pred = domain_classifier(target_features, lambda_)
                #now we will calculate the loss for the domain classifier
                domain_classifier_loss = loss_fn_domain(source_domain_pred, source_domain_labels) + loss_fn_domain(target_domain_pred, target_domain_labels)

                #now we will calculate the total loss using the parameter: C
                t_loss = class_classifier_loss + C * domain_classifier_loss

                #now we will calculate the gradients
                t_loss.backward()
                #now we will update the parameters
                optimizer.step()

                #add the loss to the epoch_total_loss
                epoch_total_loss += t_loss.item()
                epoch_total_class_loss += class_classifier_loss.item()
                epoch_total_domain_loss += domain_classifier_loss.item()
                #add loss to total loss
                # total_loss += t_loss.item()

                #now we will calculate the accuracy of the class classifier
                _, predicted = torch.max(source_class_pred.data, 1)
                temp_total_class_classifier += source_labels.size(0)
                temp_correct_class_classifier += (predicted == source_labels).sum().item()
                #add the total and correct to total, correct and epoch_total, epoch_correct
                total_class_classifier += temp_total_class_classifier
                correct_class_classifier += temp_correct_class_classifier
                epoch_total_class_classifier += temp_total_class_classifier
                epoch_correct_class_classifier += temp_correct_class_classifier

                #now we will calculate the accuracy of the domain classifier
                _, predicted_source = torch.max(source_domain_pred.data, 1)
                temp_total_source_domain_classifier = source_domain_labels.size(0)
                temp_correct_source_domain_classifier = (predicted_source == source_domain_labels).sum().item()
                

                _, predicted_target = torch.max(target_domain_pred.data, 1)
                temp_total_target_domain_classifier = target_domain_labels.size(0)
                temp_correct_target_domain_classifier = (predicted_target == target_domain_labels).sum().item()

                epoch_total_source_domain_classifier += temp_total_source_domain_classifier
                epoch_correct_source_domain_classifier += temp_correct_source_domain_classifier
                epoch_total_target_domain_classifier += temp_total_target_domain_classifier
                epoch_correct_target_domain_classifier += temp_correct_target_domain_classifier

                temp_total_domain_classifier = temp_total_source_domain_classifier + temp_total_target_domain_classifier
                temp_correct_domain_classifier = temp_correct_source_domain_classifier + temp_correct_target_domain_classifier
                #add the total and correct to total, correct and epoch_total, epoch_correct
                total_domain_classifier += temp_total_domain_classifier
                correct_domain_classifier += temp_correct_domain_classifier
                epoch_total_domain_classifier += temp_total_domain_classifier
                epoch_correct_domain_classifier += temp_correct_domain_classifier

                #now we will print the loss and accuracy based on the temp values
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tClass Loss: {:.6f}\tDomain Loss: {:.6f}\tClass Accuracy: {}/{} ({:.0f}%)\tDomain Accuracy: {}/{} ({:.0f}%)'.format(
                    epoch, batch_idx_source * len(source_data), len(source_data_loader.dataset),
                    100. * batch_idx_source / len(source_data_loader), class_classifier_loss.item(), domain_classifier_loss.item(),
                    temp_correct_class_classifier, temp_total_class_classifier,
                    100. * temp_correct_class_classifier / temp_total_class_classifier, temp_correct_domain_classifier, temp_total_domain_classifier,
                    100. * temp_correct_domain_classifier / temp_total_domain_classifier))
                
                #we will also write the loss and accuracy to the tensorboard based on temp values
                #write the loss to tensorboard as BATCH_LOSS
                writer.add_scalar('BATCH_Train_Total_Loss', t_loss.item(), global_step=batch_idx_source)
                writer.add_scalar('BATCH_Train_Class_Loss', class_classifier_loss.item(), global_step=batch_tracker)
                writer.add_scalar('BATCH_Train_Domain_Loss', domain_classifier_loss.item(), global_step=batch_tracker)
                writer.add_scalar('BATCH_Train_Class_Accuracy', 100. * temp_correct_class_classifier / temp_total_class_classifier, global_step=batch_tracker)
                writer.add_scalar('BATCH_Train_Domain_Accuracy', 100. * temp_correct_domain_classifier / temp_total_domain_classifier, global_step=batch_tracker)
                #accuracy of domain classifier on source data
                writer.add_scalar('BATCH_Train_Source_Domain_Accuracy', 100. * temp_correct_source_domain_classifier / temp_total_source_domain_classifier, global_step=batch_tracker)
                #accuracy of domain classifier on target data
                writer.add_scalar('BATCH_Train_Target_Domain_Accuracy', 100. * temp_correct_target_domain_classifier / temp_total_target_domain_classifier, global_step=batch_tracker)




                batch_tracker += 1

        #if epoch is 0 , then we will save the models and store best accuracy and epoch
        if epoch == 0:
            #save the model
            #call the save model function
            save_model(feature_extractor, class_classifier, domain_classifier, epoch)
            #store the best accuracy and epoch
            best_accuracy = 100. * epoch_correct_class_classifier / epoch_total_class_classifier
            best_epoch = epoch
    #now we will print the total accuracy for the training data
    #now we will print the total accuracy for the training data
    total_class_classifier_accuracy = 100. * correct_class_classifier / total_class_classifier
    total_domain_classifier_accuracy = 100. * correct_domain_classifier / total_domain_classifier
    print('Train Accuracy Class Classifier: {}/{} ({:.0f}%)'.format(correct_class_classifier, total_class_classifier, total_class_classifier_accuracy))
    print('Train Accuracy Domain Classifier: {}/{} ({:.0f}%)'.format(correct_domain_classifier, total_domain_classifier, total_domain_classifier_accuracy))
    #we will also write the loss and accuracy to the tensorboard based on total values
    writer.add_scalar('TOTAL_Train_Class_Accuracy', total_class_classifier_accuracy, global_step=0)
    writer.add_scalar('TOTAL_Train_Domain_Accuracy', total_domain_classifier_accuracy, global_step=0)
    #save the model
    #call the save model function
    save_model(feature_extractor, class_classifier, domain_classifier, epoch= EPOCHS)
    #print the best accuracy and epoch
    print('Best Accuracy: {:.0f}% at Epoch: {}'.format(best_epoch_accuracy, best_epoch))


    #close the writer
    writer.close()

    #return models
    return feature_extractor, class_classifier, domain_classifier

# %%
#
#test the function on the models and data
feature_extractor, class_classifier, domain_classifier = DANN_training(feature_extractor, class_classifier, domain_classifier,train_loader,test_loader)
# Out:
# /tmp/ipykernel_324708/1062286346.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# /tmp/ipykernel_324708/3753341005.py:29: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# Train Epoch: 0 [0/60000 (0%)]	Class Loss: 2.302761	Domain Loss: 1.400267	Class Accuracy: 10/64 (16%)	Domain Accuracy: 60/128 (47%)
# Train Epoch: 0 [64/60000 (0%)]	Class Loss: 2.292382	Domain Loss: 1.370552	Class Accuracy: 19/64 (30%)	Domain Accuracy: 76/128 (59%)
# Train Epoch: 0 [128/60000 (0%)]	Class Loss: 2.285094	Domain Loss: 1.601474	Class Accuracy: 11/64 (17%)	Domain Accuracy: 34/128 (27%)
# Train Epoch: 0 [192/60000 (0%)]	Class Loss: 2.272297	Domain Loss: 1.980589	Class Accuracy: 10/64 (16%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [256/60000 (0%)]	Class Loss: 2.244064	Domain Loss: 2.309478	Class Accuracy: 16/64 (25%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [320/60000 (1%)]	Class Loss: 2.235076	Domain Loss: 2.515827	Class Accuracy: 12/64 (19%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [384/60000 (1%)]	Class Loss: 2.145733	Domain Loss: 2.572023	Class Accuracy: 26/64 (41%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [448/60000 (1%)]	Class Loss: 2.102596	Domain Loss: 2.591555	Class Accuracy: 30/64 (47%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [512/60000 (1%)]	Class Loss: 2.007201	Domain Loss: 2.602224	Class Accuracy: 43/64 (67%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [576/60000 (1%)]	Class Loss: 1.900778	Domain Loss: 2.603586	Class Accuracy: 45/64 (70%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [640/60000 (1%)]	Class Loss: 1.790967	Domain Loss: 2.602629	Class Accuracy: 50/64 (78%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [704/60000 (1%)]	Class Loss: 1.751298	Domain Loss: 2.593687	Class Accuracy: 48/64 (75%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [768/60000 (1%)]	Class Loss: 1.751712	Domain Loss: 2.580609	Class Accuracy: 48/64 (75%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [832/60000 (1%)]	Class Loss: 1.632139	Domain Loss: 2.559561	Class Accuracy: 55/64 (86%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [896/60000 (1%)]	Class Loss: 1.709970	Domain Loss: 2.516194	Class Accuracy: 48/64 (75%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [960/60000 (2%)]	Class Loss: 1.701138	Domain Loss: 2.453498	Class Accuracy: 50/64 (78%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [1024/60000 (2%)]	Class Loss: 1.699145	Domain Loss: 2.364756	Class Accuracy: 49/64 (77%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [1088/60000 (2%)]	Class Loss: 1.796602	Domain Loss: 2.275565	Class Accuracy: 43/64 (67%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [1152/60000 (2%)]	Class Loss: 1.770740	Domain Loss: 2.162647	Class Accuracy: 44/64 (69%)	Domain Accuracy: 0/128 (0%)
# Train Epoch: 0 [1216/60000 (2%)]	Class Loss: 1.665534	Domain Loss: 2.060135	Class Accuracy: 52/64 (81%)	Domain Accuracy: 1/128 (1%)
# Train Epoch: 0 [1280/60000 (2%)]	Class Loss: 1.740935	Domain Loss: 1.972608	Class Accuracy: 47/64 (73%)	Domain Accuracy: 57/128 (45%)
# Train Epoch: 0 [1344/60000 (2%)]	Class Loss: 1.731559	Domain Loss: 1.905090	Class Accuracy: 46/64 (72%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1408/60000 (2%)]	Class Loss: 1.741171	Domain Loss: 1.866790	Class Accuracy: 45/64 (70%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1472/60000 (2%)]	Class Loss: 1.676911	Domain Loss: 1.847343	Class Accuracy: 50/64 (78%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1536/60000 (3%)]	Class Loss: 1.622928	Domain Loss: 1.844164	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1600/60000 (3%)]	Class Loss: 1.640326	Domain Loss: 1.848975	Class Accuracy: 53/64 (83%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1664/60000 (3%)]	Class Loss: 1.714567	Domain Loss: 1.871229	Class Accuracy: 48/64 (75%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1728/60000 (3%)]	Class Loss: 1.668324	Domain Loss: 1.909777	Class Accuracy: 50/64 (78%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1792/60000 (3%)]	Class Loss: 1.760771	Domain Loss: 1.936053	Class Accuracy: 45/64 (70%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1856/60000 (3%)]	Class Loss: 1.781251	Domain Loss: 1.957663	Class Accuracy: 43/64 (67%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1920/60000 (3%)]	Class Loss: 1.733821	Domain Loss: 1.972903	Class Accuracy: 45/64 (70%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [1984/60000 (3%)]	Class Loss: 1.648271	Domain Loss: 1.981642	Class Accuracy: 51/64 (80%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2048/60000 (3%)]	Class Loss: 1.684503	Domain Loss: 1.986242	Class Accuracy: 50/64 (78%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2112/60000 (4%)]	Class Loss: 1.652770	Domain Loss: 1.987083	Class Accuracy: 53/64 (83%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2176/60000 (4%)]	Class Loss: 1.668755	Domain Loss: 1.988075	Class Accuracy: 53/64 (83%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2240/60000 (4%)]	Class Loss: 1.646331	Domain Loss: 1.988696	Class Accuracy: 53/64 (83%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2304/60000 (4%)]	Class Loss: 1.666154	Domain Loss: 1.989349	Class Accuracy: 52/64 (81%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2368/60000 (4%)]	Class Loss: 1.701224	Domain Loss: 1.988836	Class Accuracy: 49/64 (77%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2432/60000 (4%)]	Class Loss: 1.659621	Domain Loss: 1.988812	Class Accuracy: 51/64 (80%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2496/60000 (4%)]	Class Loss: 1.621739	Domain Loss: 1.988347	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2560/60000 (4%)]	Class Loss: 1.633206	Domain Loss: 1.987424	Class Accuracy: 53/64 (83%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2624/60000 (4%)]	Class Loss: 1.663004	Domain Loss: 1.986395	Class Accuracy: 51/64 (80%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2688/60000 (4%)]	Class Loss: 1.602199	Domain Loss: 1.985626	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2752/60000 (5%)]	Class Loss: 1.610605	Domain Loss: 1.984911	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2816/60000 (5%)]	Class Loss: 1.580867	Domain Loss: 1.984496	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2880/60000 (5%)]	Class Loss: 1.598403	Domain Loss: 1.984323	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [2944/60000 (5%)]	Class Loss: 1.549812	Domain Loss: 1.984191	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3008/60000 (5%)]	Class Loss: 1.541805	Domain Loss: 1.983677	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3072/60000 (5%)]	Class Loss: 1.567862	Domain Loss: 1.983203	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3136/60000 (5%)]	Class Loss: 1.623053	Domain Loss: 1.982512	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3200/60000 (5%)]	Class Loss: 1.649956	Domain Loss: 1.981979	Class Accuracy: 52/64 (81%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3264/60000 (5%)]	Class Loss: 1.583757	Domain Loss: 1.981337	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3328/60000 (6%)]	Class Loss: 1.574390	Domain Loss: 1.980705	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3392/60000 (6%)]	Class Loss: 1.588305	Domain Loss: 1.980107	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3456/60000 (6%)]	Class Loss: 1.601549	Domain Loss: 1.979573	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3520/60000 (6%)]	Class Loss: 1.569453	Domain Loss: 1.979100	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3584/60000 (6%)]	Class Loss: 1.551157	Domain Loss: 1.978595	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3648/60000 (6%)]	Class Loss: 1.603786	Domain Loss: 1.978012	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3712/60000 (6%)]	Class Loss: 1.531329	Domain Loss: 1.977443	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3776/60000 (6%)]	Class Loss: 1.584284	Domain Loss: 1.976907	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3840/60000 (6%)]	Class Loss: 1.654764	Domain Loss: 1.976441	Class Accuracy: 52/64 (81%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3904/60000 (7%)]	Class Loss: 1.607024	Domain Loss: 1.975978	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [3968/60000 (7%)]	Class Loss: 1.567786	Domain Loss: 1.975476	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4032/60000 (7%)]	Class Loss: 1.547909	Domain Loss: 1.974913	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4096/60000 (7%)]	Class Loss: 1.578569	Domain Loss: 1.974339	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4160/60000 (7%)]	Class Loss: 1.620386	Domain Loss: 1.973756	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4224/60000 (7%)]	Class Loss: 1.606456	Domain Loss: 1.973049	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4288/60000 (7%)]	Class Loss: 1.617531	Domain Loss: 1.972069	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4352/60000 (7%)]	Class Loss: 1.638567	Domain Loss: 1.971862	Class Accuracy: 53/64 (83%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4416/60000 (7%)]	Class Loss: 1.666557	Domain Loss: 1.971171	Class Accuracy: 51/64 (80%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4480/60000 (7%)]	Class Loss: 1.579524	Domain Loss: 1.970381	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4544/60000 (8%)]	Class Loss: 1.587907	Domain Loss: 1.969795	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4608/60000 (8%)]	Class Loss: 1.587494	Domain Loss: 1.969351	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4672/60000 (8%)]	Class Loss: 1.551361	Domain Loss: 1.968975	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4736/60000 (8%)]	Class Loss: 1.640525	Domain Loss: 1.968537	Class Accuracy: 52/64 (81%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4800/60000 (8%)]	Class Loss: 1.624853	Domain Loss: 1.967957	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4864/60000 (8%)]	Class Loss: 1.576090	Domain Loss: 1.967396	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4928/60000 (8%)]	Class Loss: 1.555058	Domain Loss: 1.966939	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [4992/60000 (8%)]	Class Loss: 1.583793	Domain Loss: 1.966487	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5056/60000 (8%)]	Class Loss: 1.534206	Domain Loss: 1.965881	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5120/60000 (9%)]	Class Loss: 1.682330	Domain Loss: 1.965434	Class Accuracy: 50/64 (78%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5184/60000 (9%)]	Class Loss: 1.550506	Domain Loss: 1.964838	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5248/60000 (9%)]	Class Loss: 1.599386	Domain Loss: 1.964278	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5312/60000 (9%)]	Class Loss: 1.602670	Domain Loss: 1.963753	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5376/60000 (9%)]	Class Loss: 1.603866	Domain Loss: 1.963199	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5440/60000 (9%)]	Class Loss: 1.556898	Domain Loss: 1.962740	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5504/60000 (9%)]	Class Loss: 1.603957	Domain Loss: 1.962356	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5568/60000 (9%)]	Class Loss: 1.622869	Domain Loss: 1.961826	Class Accuracy: 55/64 (86%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5632/60000 (9%)]	Class Loss: 1.637968	Domain Loss: 1.961278	Class Accuracy: 53/64 (83%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5696/60000 (9%)]	Class Loss: 1.615110	Domain Loss: 1.960671	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5760/60000 (10%)]	Class Loss: 1.580187	Domain Loss: 1.960055	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5824/60000 (10%)]	Class Loss: 1.528533	Domain Loss: 1.959333	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5888/60000 (10%)]	Class Loss: 1.571966	Domain Loss: 1.958599	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [5952/60000 (10%)]	Class Loss: 1.548353	Domain Loss: 1.958430	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6016/60000 (10%)]	Class Loss: 1.510472	Domain Loss: 1.957498	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6080/60000 (10%)]	Class Loss: 1.542293	Domain Loss: 1.957489	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6144/60000 (10%)]	Class Loss: 1.593401	Domain Loss: 1.957021	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6208/60000 (10%)]	Class Loss: 1.581859	Domain Loss: 1.956519	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6272/60000 (10%)]	Class Loss: 1.581302	Domain Loss: 1.956011	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6336/60000 (11%)]	Class Loss: 1.564813	Domain Loss: 1.955517	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6400/60000 (11%)]	Class Loss: 1.504548	Domain Loss: 1.955018	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6464/60000 (11%)]	Class Loss: 1.540836	Domain Loss: 1.954513	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6528/60000 (11%)]	Class Loss: 1.495576	Domain Loss: 1.953982	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6592/60000 (11%)]	Class Loss: 1.553836	Domain Loss: 1.953459	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6656/60000 (11%)]	Class Loss: 1.544992	Domain Loss: 1.952939	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6720/60000 (11%)]	Class Loss: 1.520672	Domain Loss: 1.952481	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6784/60000 (11%)]	Class Loss: 1.527076	Domain Loss: 1.951980	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6848/60000 (11%)]	Class Loss: 1.478002	Domain Loss: 1.951122	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6912/60000 (12%)]	Class Loss: 1.508326	Domain Loss: 1.951150	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6976/60000 (12%)]	Class Loss: 1.481441	Domain Loss: 1.950585	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7040/60000 (12%)]	Class Loss: 1.558903	Domain Loss: 1.950101	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7104/60000 (12%)]	Class Loss: 1.492948	Domain Loss: 1.949324	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7168/60000 (12%)]	Class Loss: 1.500666	Domain Loss: 1.948871	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [6667/60000 (12%)]	Class Loss: 1.610571	Domain Loss: 1.948480	Class Accuracy: 50/59 (85%)	Domain Accuracy: 59/118 (50%)
# Train Epoch: 0 [7296/60000 (12%)]	Class Loss: 1.532871	Domain Loss: 1.948023	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7360/60000 (12%)]	Class Loss: 1.529074	Domain Loss: 1.947650	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7424/60000 (12%)]	Class Loss: 1.516266	Domain Loss: 1.947089	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7488/60000 (12%)]	Class Loss: 1.513381	Domain Loss: 1.946635	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7552/60000 (13%)]	Class Loss: 1.497018	Domain Loss: 1.946143	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7616/60000 (13%)]	Class Loss: 1.467546	Domain Loss: 1.945661	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7680/60000 (13%)]	Class Loss: 1.530351	Domain Loss: 1.945181	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7744/60000 (13%)]	Class Loss: 1.517629	Domain Loss: 1.944743	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7808/60000 (13%)]	Class Loss: 1.489621	Domain Loss: 1.944324	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7872/60000 (13%)]	Class Loss: 1.516456	Domain Loss: 1.943772	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [7936/60000 (13%)]	Class Loss: 1.490584	Domain Loss: 1.943109	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8000/60000 (13%)]	Class Loss: 1.538372	Domain Loss: 1.942430	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8064/60000 (13%)]	Class Loss: 1.504927	Domain Loss: 1.941830	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8128/60000 (14%)]	Class Loss: 1.579008	Domain Loss: 1.941525	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8192/60000 (14%)]	Class Loss: 1.521573	Domain Loss: 1.941221	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8256/60000 (14%)]	Class Loss: 1.512111	Domain Loss: 1.940603	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8320/60000 (14%)]	Class Loss: 1.501876	Domain Loss: 1.939935	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8384/60000 (14%)]	Class Loss: 1.499226	Domain Loss: 1.939651	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8448/60000 (14%)]	Class Loss: 1.514902	Domain Loss: 1.939335	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8512/60000 (14%)]	Class Loss: 1.522131	Domain Loss: 1.938952	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8576/60000 (14%)]	Class Loss: 1.565902	Domain Loss: 1.938350	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8640/60000 (14%)]	Class Loss: 1.523439	Domain Loss: 1.938068	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8704/60000 (14%)]	Class Loss: 1.481677	Domain Loss: 1.937633	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8768/60000 (15%)]	Class Loss: 1.495716	Domain Loss: 1.937312	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8832/60000 (15%)]	Class Loss: 1.469296	Domain Loss: 1.936868	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8896/60000 (15%)]	Class Loss: 1.526531	Domain Loss: 1.936441	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [8960/60000 (15%)]	Class Loss: 1.507227	Domain Loss: 1.935864	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9024/60000 (15%)]	Class Loss: 1.503051	Domain Loss: 1.934709	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9088/60000 (15%)]	Class Loss: 1.485983	Domain Loss: 1.933790	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9152/60000 (15%)]	Class Loss: 1.529964	Domain Loss: 1.932590	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9216/60000 (15%)]	Class Loss: 1.502666	Domain Loss: 1.931178	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9280/60000 (15%)]	Class Loss: 1.467898	Domain Loss: 1.930754	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9344/60000 (16%)]	Class Loss: 1.521549	Domain Loss: 1.932011	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9408/60000 (16%)]	Class Loss: 1.532887	Domain Loss: 1.932233	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9472/60000 (16%)]	Class Loss: 1.541979	Domain Loss: 1.931866	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9536/60000 (16%)]	Class Loss: 1.511532	Domain Loss: 1.931408	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9600/60000 (16%)]	Class Loss: 1.503921	Domain Loss: 1.931093	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9664/60000 (16%)]	Class Loss: 1.512587	Domain Loss: 1.930614	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9728/60000 (16%)]	Class Loss: 1.542392	Domain Loss: 1.930020	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9792/60000 (16%)]	Class Loss: 1.519150	Domain Loss: 1.929663	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9856/60000 (16%)]	Class Loss: 1.520939	Domain Loss: 1.929201	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9920/60000 (17%)]	Class Loss: 1.510371	Domain Loss: 1.928784	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [9984/60000 (17%)]	Class Loss: 1.529169	Domain Loss: 1.928259	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10048/60000 (17%)]	Class Loss: 1.514514	Domain Loss: 1.927554	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10112/60000 (17%)]	Class Loss: 1.538188	Domain Loss: 1.626726	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10176/60000 (17%)]	Class Loss: 1.487933	Domain Loss: 1.626526	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10240/60000 (17%)]	Class Loss: 1.522995	Domain Loss: 1.626526	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10304/60000 (17%)]	Class Loss: 1.535985	Domain Loss: 1.626582	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10368/60000 (17%)]	Class Loss: 1.499993	Domain Loss: 1.626526	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10432/60000 (17%)]	Class Loss: 1.519663	Domain Loss: 1.626532	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10496/60000 (17%)]	Class Loss: 1.507737	Domain Loss: 1.626525	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10560/60000 (18%)]	Class Loss: 1.524549	Domain Loss: 1.626560	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10624/60000 (18%)]	Class Loss: 1.521600	Domain Loss: 1.626526	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10688/60000 (18%)]	Class Loss: 1.462058	Domain Loss: 1.626527	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10752/60000 (18%)]	Class Loss: 1.524953	Domain Loss: 1.626528	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10816/60000 (18%)]	Class Loss: 1.511327	Domain Loss: 1.626525	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10880/60000 (18%)]	Class Loss: 1.576130	Domain Loss: 1.626548	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [10944/60000 (18%)]	Class Loss: 1.552735	Domain Loss: 1.626538	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11008/60000 (18%)]	Class Loss: 1.471639	Domain Loss: 1.626555	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11072/60000 (18%)]	Class Loss: 1.477008	Domain Loss: 1.626525	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11136/60000 (19%)]	Class Loss: 1.521110	Domain Loss: 1.626552	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11200/60000 (19%)]	Class Loss: 1.478294	Domain Loss: 1.626551	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11264/60000 (19%)]	Class Loss: 1.530944	Domain Loss: 1.626557	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11328/60000 (19%)]	Class Loss: 1.503852	Domain Loss: 1.626534	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11392/60000 (19%)]	Class Loss: 1.523157	Domain Loss: 1.626526	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11456/60000 (19%)]	Class Loss: 1.501831	Domain Loss: 1.626536	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11520/60000 (19%)]	Class Loss: 1.512870	Domain Loss: 1.626531	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11584/60000 (19%)]	Class Loss: 1.522832	Domain Loss: 1.626525	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11648/60000 (19%)]	Class Loss: 1.468897	Domain Loss: 1.626704	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11712/60000 (20%)]	Class Loss: 1.528782	Domain Loss: 1.626528	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11776/60000 (20%)]	Class Loss: 1.535243	Domain Loss: 1.626527	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11840/60000 (20%)]	Class Loss: 1.488724	Domain Loss: 1.626579	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11904/60000 (20%)]	Class Loss: 1.508808	Domain Loss: 1.626526	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [11968/60000 (20%)]	Class Loss: 1.572424	Domain Loss: 1.626531	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12032/60000 (20%)]	Class Loss: 1.504769	Domain Loss: 1.626944	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12096/60000 (20%)]	Class Loss: 1.487996	Domain Loss: 1.626581	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12160/60000 (20%)]	Class Loss: 1.478068	Domain Loss: 1.626524	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12224/60000 (20%)]	Class Loss: 1.490211	Domain Loss: 1.626525	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12288/60000 (20%)]	Class Loss: 1.524021	Domain Loss: 1.626537	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12352/60000 (21%)]	Class Loss: 1.487901	Domain Loss: 1.626536	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12416/60000 (21%)]	Class Loss: 1.479187	Domain Loss: 1.626544	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12480/60000 (21%)]	Class Loss: 1.539299	Domain Loss: 1.626524	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12544/60000 (21%)]	Class Loss: 1.556475	Domain Loss: 1.626601	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12608/60000 (21%)]	Class Loss: 1.499816	Domain Loss: 1.626553	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12672/60000 (21%)]	Class Loss: 1.497677	Domain Loss: 1.626687	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12736/60000 (21%)]	Class Loss: 1.480873	Domain Loss: 1.626536	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12800/60000 (21%)]	Class Loss: 1.531322	Domain Loss: 1.626719	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12864/60000 (21%)]	Class Loss: 1.500920	Domain Loss: 1.626526	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12928/60000 (22%)]	Class Loss: 1.506757	Domain Loss: 1.626607	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [12992/60000 (22%)]	Class Loss: 1.496515	Domain Loss: 1.626532	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13056/60000 (22%)]	Class Loss: 1.515096	Domain Loss: 1.626583	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13120/60000 (22%)]	Class Loss: 1.496493	Domain Loss: 1.626718	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13184/60000 (22%)]	Class Loss: 1.481155	Domain Loss: 1.626563	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13248/60000 (22%)]	Class Loss: 1.523304	Domain Loss: 1.626550	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13312/60000 (22%)]	Class Loss: 1.500779	Domain Loss: 1.626595	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13376/60000 (22%)]	Class Loss: 1.533244	Domain Loss: 1.626555	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13440/60000 (22%)]	Class Loss: 1.486734	Domain Loss: 1.627243	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13504/60000 (22%)]	Class Loss: 1.572789	Domain Loss: 1.626566	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13568/60000 (23%)]	Class Loss: 1.538200	Domain Loss: 1.627470	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13632/60000 (23%)]	Class Loss: 1.542838	Domain Loss: 1.626619	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13696/60000 (23%)]	Class Loss: 1.512743	Domain Loss: 1.626653	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13760/60000 (23%)]	Class Loss: 1.532825	Domain Loss: 1.626645	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13824/60000 (23%)]	Class Loss: 1.493877	Domain Loss: 1.626590	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13888/60000 (23%)]	Class Loss: 1.488224	Domain Loss: 1.626657	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13952/60000 (23%)]	Class Loss: 1.499344	Domain Loss: 1.626558	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14016/60000 (23%)]	Class Loss: 1.508433	Domain Loss: 1.626588	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14080/60000 (23%)]	Class Loss: 1.479331	Domain Loss: 1.626740	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14144/60000 (24%)]	Class Loss: 1.475780	Domain Loss: 1.626924	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14208/60000 (24%)]	Class Loss: 1.521242	Domain Loss: 1.627131	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14272/60000 (24%)]	Class Loss: 1.508220	Domain Loss: 1.626541	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14336/60000 (24%)]	Class Loss: 1.515278	Domain Loss: 1.626732	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14400/60000 (24%)]	Class Loss: 1.518014	Domain Loss: 1.626628	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14464/60000 (24%)]	Class Loss: 1.543859	Domain Loss: 1.626974	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [13393/60000 (24%)]	Class Loss: 1.525298	Domain Loss: 1.626570	Class Accuracy: 55/59 (93%)	Domain Accuracy: 59/118 (50%)
# Train Epoch: 0 [14592/60000 (24%)]	Class Loss: 1.477628	Domain Loss: 1.626864	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14656/60000 (24%)]	Class Loss: 1.536610	Domain Loss: 1.627103	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14720/60000 (25%)]	Class Loss: 1.481045	Domain Loss: 1.626931	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14784/60000 (25%)]	Class Loss: 1.508101	Domain Loss: 1.626730	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14848/60000 (25%)]	Class Loss: 1.494923	Domain Loss: 1.626719	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14912/60000 (25%)]	Class Loss: 1.553852	Domain Loss: 1.626969	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [14976/60000 (25%)]	Class Loss: 1.479030	Domain Loss: 1.628903	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15040/60000 (25%)]	Class Loss: 1.497757	Domain Loss: 1.627392	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15104/60000 (25%)]	Class Loss: 1.486175	Domain Loss: 1.628344	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15168/60000 (25%)]	Class Loss: 1.521666	Domain Loss: 1.626741	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15232/60000 (25%)]	Class Loss: 1.481022	Domain Loss: 1.628651	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15296/60000 (25%)]	Class Loss: 1.509674	Domain Loss: 1.628317	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15360/60000 (26%)]	Class Loss: 1.481443	Domain Loss: 1.631076	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15424/60000 (26%)]	Class Loss: 1.514887	Domain Loss: 1.628644	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15488/60000 (26%)]	Class Loss: 1.516961	Domain Loss: 1.631028	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15552/60000 (26%)]	Class Loss: 1.489237	Domain Loss: 1.631319	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15616/60000 (26%)]	Class Loss: 1.489518	Domain Loss: 1.636651	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15680/60000 (26%)]	Class Loss: 1.527319	Domain Loss: 1.642724	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15744/60000 (26%)]	Class Loss: 1.490120	Domain Loss: 1.650065	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15808/60000 (26%)]	Class Loss: 1.507676	Domain Loss: 1.649027	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15872/60000 (26%)]	Class Loss: 1.492853	Domain Loss: 1.650886	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [15936/60000 (27%)]	Class Loss: 1.471327	Domain Loss: 1.683855	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16000/60000 (27%)]	Class Loss: 1.462230	Domain Loss: 1.703156	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16064/60000 (27%)]	Class Loss: 1.488269	Domain Loss: 1.712704	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16128/60000 (27%)]	Class Loss: 1.522586	Domain Loss: 1.743146	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16192/60000 (27%)]	Class Loss: 1.511204	Domain Loss: 1.754629	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16256/60000 (27%)]	Class Loss: 1.529040	Domain Loss: 1.788134	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16320/60000 (27%)]	Class Loss: 1.488412	Domain Loss: 1.797827	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16384/60000 (27%)]	Class Loss: 1.486401	Domain Loss: 1.831794	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16448/60000 (27%)]	Class Loss: 1.470256	Domain Loss: 1.875910	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16512/60000 (28%)]	Class Loss: 1.486285	Domain Loss: 1.763625	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16576/60000 (28%)]	Class Loss: 1.503881	Domain Loss: 1.872085	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16640/60000 (28%)]	Class Loss: 1.498512	Domain Loss: 1.854530	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16704/60000 (28%)]	Class Loss: 1.518734	Domain Loss: 1.857472	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16768/60000 (28%)]	Class Loss: 1.478948	Domain Loss: 1.849161	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16832/60000 (28%)]	Class Loss: 1.488004	Domain Loss: 1.866556	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16896/60000 (28%)]	Class Loss: 1.508112	Domain Loss: 1.865543	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [16960/60000 (28%)]	Class Loss: 1.523984	Domain Loss: 1.870422	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17024/60000 (28%)]	Class Loss: 1.506631	Domain Loss: 1.881835	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17088/60000 (28%)]	Class Loss: 1.480928	Domain Loss: 1.886086	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17152/60000 (29%)]	Class Loss: 1.514879	Domain Loss: 1.887064	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17216/60000 (29%)]	Class Loss: 1.492167	Domain Loss: 1.904797	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17280/60000 (29%)]	Class Loss: 1.522011	Domain Loss: 1.895706	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17344/60000 (29%)]	Class Loss: 1.531630	Domain Loss: 1.867389	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17408/60000 (29%)]	Class Loss: 1.494460	Domain Loss: 1.880502	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17472/60000 (29%)]	Class Loss: 1.524036	Domain Loss: 1.883562	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17536/60000 (29%)]	Class Loss: 1.500555	Domain Loss: 1.898878	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17600/60000 (29%)]	Class Loss: 1.496294	Domain Loss: 1.878321	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17664/60000 (29%)]	Class Loss: 1.542192	Domain Loss: 1.904238	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17728/60000 (30%)]	Class Loss: 1.474117	Domain Loss: 1.903844	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17792/60000 (30%)]	Class Loss: 1.479455	Domain Loss: 1.905677	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17856/60000 (30%)]	Class Loss: 1.467671	Domain Loss: 1.900584	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17920/60000 (30%)]	Class Loss: 1.498704	Domain Loss: 1.886733	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [17984/60000 (30%)]	Class Loss: 1.517294	Domain Loss: 1.893085	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18048/60000 (30%)]	Class Loss: 1.501673	Domain Loss: 1.893675	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18112/60000 (30%)]	Class Loss: 1.487852	Domain Loss: 1.889236	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18176/60000 (30%)]	Class Loss: 1.608753	Domain Loss: 1.893427	Class Accuracy: 54/64 (84%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18240/60000 (30%)]	Class Loss: 1.562060	Domain Loss: 1.882582	Class Accuracy: 56/64 (88%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18304/60000 (30%)]	Class Loss: 1.539034	Domain Loss: 1.887603	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18368/60000 (31%)]	Class Loss: 1.504245	Domain Loss: 1.901382	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18432/60000 (31%)]	Class Loss: 1.491563	Domain Loss: 1.892968	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18496/60000 (31%)]	Class Loss: 1.509901	Domain Loss: 1.896622	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18560/60000 (31%)]	Class Loss: 1.504801	Domain Loss: 1.900054	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18624/60000 (31%)]	Class Loss: 1.542666	Domain Loss: 1.890712	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18688/60000 (31%)]	Class Loss: 1.576592	Domain Loss: 1.892947	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18752/60000 (31%)]	Class Loss: 1.533169	Domain Loss: 1.902844	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18816/60000 (31%)]	Class Loss: 1.571715	Domain Loss: 1.902582	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18880/60000 (31%)]	Class Loss: 1.511337	Domain Loss: 1.891636	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [18944/60000 (32%)]	Class Loss: 1.508880	Domain Loss: 1.895933	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19008/60000 (32%)]	Class Loss: 1.504957	Domain Loss: 1.893225	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19072/60000 (32%)]	Class Loss: 1.480071	Domain Loss: 1.899069	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19136/60000 (32%)]	Class Loss: 1.489629	Domain Loss: 1.896943	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19200/60000 (32%)]	Class Loss: 1.491362	Domain Loss: 1.899467	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19264/60000 (32%)]	Class Loss: 1.561946	Domain Loss: 1.896219	Class Accuracy: 58/64 (91%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19328/60000 (32%)]	Class Loss: 1.481581	Domain Loss: 1.899338	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19392/60000 (32%)]	Class Loss: 1.525760	Domain Loss: 1.899387	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19456/60000 (32%)]	Class Loss: 1.533315	Domain Loss: 1.899302	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19520/60000 (33%)]	Class Loss: 1.501749	Domain Loss: 1.899222	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19584/60000 (33%)]	Class Loss: 1.504060	Domain Loss: 1.899439	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19648/60000 (33%)]	Class Loss: 1.517148	Domain Loss: 1.899678	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19712/60000 (33%)]	Class Loss: 1.509868	Domain Loss: 1.899348	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19776/60000 (33%)]	Class Loss: 1.508420	Domain Loss: 1.898826	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19840/60000 (33%)]	Class Loss: 1.478171	Domain Loss: 1.898450	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19904/60000 (33%)]	Class Loss: 1.475433	Domain Loss: 1.898038	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [19968/60000 (33%)]	Class Loss: 1.497247	Domain Loss: 1.897657	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20032/60000 (33%)]	Class Loss: 1.486485	Domain Loss: 1.897675	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20096/60000 (33%)]	Class Loss: 1.525551	Domain Loss: 1.897085	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20160/60000 (34%)]	Class Loss: 1.475327	Domain Loss: 1.896910	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20224/60000 (34%)]	Class Loss: 1.526928	Domain Loss: 1.896370	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20288/60000 (34%)]	Class Loss: 1.515025	Domain Loss: 1.895700	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20352/60000 (34%)]	Class Loss: 1.503731	Domain Loss: 1.895110	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20416/60000 (34%)]	Class Loss: 1.530005	Domain Loss: 1.894318	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20480/60000 (34%)]	Class Loss: 1.467228	Domain Loss: 1.893162	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20544/60000 (34%)]	Class Loss: 1.496557	Domain Loss: 1.893255	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20608/60000 (34%)]	Class Loss: 1.489663	Domain Loss: 1.892730	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20672/60000 (34%)]	Class Loss: 1.464356	Domain Loss: 1.892366	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20736/60000 (35%)]	Class Loss: 1.510887	Domain Loss: 1.892107	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20800/60000 (35%)]	Class Loss: 1.516455	Domain Loss: 1.891704	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20864/60000 (35%)]	Class Loss: 1.494028	Domain Loss: 1.891508	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20928/60000 (35%)]	Class Loss: 1.477745	Domain Loss: 1.891066	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20992/60000 (35%)]	Class Loss: 1.508731	Domain Loss: 1.890482	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21056/60000 (35%)]	Class Loss: 1.484795	Domain Loss: 1.890081	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21120/60000 (35%)]	Class Loss: 1.535679	Domain Loss: 1.889642	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21184/60000 (35%)]	Class Loss: 1.489491	Domain Loss: 1.889202	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21248/60000 (35%)]	Class Loss: 1.522588	Domain Loss: 1.888731	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21312/60000 (36%)]	Class Loss: 1.516033	Domain Loss: 1.888311	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21376/60000 (36%)]	Class Loss: 1.495589	Domain Loss: 1.887901	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21440/60000 (36%)]	Class Loss: 1.521535	Domain Loss: 1.887339	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21504/60000 (36%)]	Class Loss: 1.489994	Domain Loss: 1.886904	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21568/60000 (36%)]	Class Loss: 1.478936	Domain Loss: 1.886441	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21632/60000 (36%)]	Class Loss: 1.494770	Domain Loss: 1.885919	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21696/60000 (36%)]	Class Loss: 1.479140	Domain Loss: 1.885484	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21760/60000 (36%)]	Class Loss: 1.510570	Domain Loss: 1.885122	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [20119/60000 (36%)]	Class Loss: 1.509176	Domain Loss: 1.884631	Class Accuracy: 56/59 (95%)	Domain Accuracy: 59/118 (50%)
# Train Epoch: 0 [21888/60000 (36%)]	Class Loss: 1.509455	Domain Loss: 1.884179	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [21952/60000 (37%)]	Class Loss: 1.492012	Domain Loss: 1.883616	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22016/60000 (37%)]	Class Loss: 1.514532	Domain Loss: 1.883230	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22080/60000 (37%)]	Class Loss: 1.489853	Domain Loss: 1.882821	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22144/60000 (37%)]	Class Loss: 1.539531	Domain Loss: 1.882348	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22208/60000 (37%)]	Class Loss: 1.562814	Domain Loss: 1.881949	Class Accuracy: 57/64 (89%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22272/60000 (37%)]	Class Loss: 1.480781	Domain Loss: 1.881428	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22336/60000 (37%)]	Class Loss: 1.504415	Domain Loss: 1.881034	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22400/60000 (37%)]	Class Loss: 1.508350	Domain Loss: 1.880593	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22464/60000 (37%)]	Class Loss: 1.498391	Domain Loss: 1.880104	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22528/60000 (38%)]	Class Loss: 1.518319	Domain Loss: 1.879665	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22592/60000 (38%)]	Class Loss: 1.468207	Domain Loss: 1.879252	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22656/60000 (38%)]	Class Loss: 1.507740	Domain Loss: 1.878790	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22720/60000 (38%)]	Class Loss: 1.501683	Domain Loss: 1.877705	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22784/60000 (38%)]	Class Loss: 1.492311	Domain Loss: 1.877848	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22848/60000 (38%)]	Class Loss: 1.536287	Domain Loss: 1.877454	Class Accuracy: 59/64 (92%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22912/60000 (38%)]	Class Loss: 1.491621	Domain Loss: 1.877060	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [22976/60000 (38%)]	Class Loss: 1.494161	Domain Loss: 1.876562	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23040/60000 (38%)]	Class Loss: 1.470919	Domain Loss: 1.876161	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23104/60000 (38%)]	Class Loss: 1.498591	Domain Loss: 1.875727	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23168/60000 (39%)]	Class Loss: 1.512812	Domain Loss: 1.875302	Class Accuracy: 60/64 (94%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23232/60000 (39%)]	Class Loss: 1.510409	Domain Loss: 1.874882	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23296/60000 (39%)]	Class Loss: 1.519396	Domain Loss: 1.874437	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23360/60000 (39%)]	Class Loss: 1.508334	Domain Loss: 1.874027	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23424/60000 (39%)]	Class Loss: 1.476730	Domain Loss: 1.873572	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23488/60000 (39%)]	Class Loss: 1.509501	Domain Loss: 1.873155	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23552/60000 (39%)]	Class Loss: 1.477881	Domain Loss: 1.872736	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23616/60000 (39%)]	Class Loss: 1.471862	Domain Loss: 1.872305	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23680/60000 (39%)]	Class Loss: 1.461268	Domain Loss: 1.871882	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23744/60000 (40%)]	Class Loss: 1.492351	Domain Loss: 1.871457	Class Accuracy: 62/64 (97%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23808/60000 (40%)]	Class Loss: 1.476390	Domain Loss: 1.871027	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23872/60000 (40%)]	Class Loss: 1.484620	Domain Loss: 1.870612	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [23936/60000 (40%)]	Class Loss: 1.507645	Domain Loss: 1.870176	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24000/60000 (40%)]	Class Loss: 1.488566	Domain Loss: 1.869774	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24064/60000 (40%)]	Class Loss: 1.503281	Domain Loss: 1.869333	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24128/60000 (40%)]	Class Loss: 1.462535	Domain Loss: 1.868896	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24192/60000 (40%)]	Class Loss: 1.475783	Domain Loss: 1.868504	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24256/60000 (40%)]	Class Loss: 1.461879	Domain Loss: 1.868100	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24320/60000 (41%)]	Class Loss: 1.480562	Domain Loss: 1.867552	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24384/60000 (41%)]	Class Loss: 1.463382	Domain Loss: 1.867266	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24448/60000 (41%)]	Class Loss: 1.480111	Domain Loss: 1.866836	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24512/60000 (41%)]	Class Loss: 1.466456	Domain Loss: 1.866432	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24576/60000 (41%)]	Class Loss: 1.461725	Domain Loss: 1.866031	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24640/60000 (41%)]	Class Loss: 1.499819	Domain Loss: 1.865595	Class Accuracy: 61/64 (95%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24704/60000 (41%)]	Class Loss: 1.462687	Domain Loss: 1.865208	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24768/60000 (41%)]	Class Loss: 1.478759	Domain Loss: 1.864797	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24832/60000 (41%)]	Class Loss: 1.491020	Domain Loss: 1.864397	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24896/60000 (41%)]	Class Loss: 1.466021	Domain Loss: 1.863991	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [24960/60000 (42%)]	Class Loss: 1.473336	Domain Loss: 1.863589	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [25024/60000 (42%)]	Class Loss: 1.485104	Domain Loss: 1.863157	Class Accuracy: 63/64 (98%)	Domain Accuracy: 64/128 (50%)
# Train Epoch: 0 [25088/60000 (42%)]	Class Loss: 1.463165	Domain Loss: 1.862716	Class Accuracy: 64/64 (100%)	Domain Accuracy: 64/128 (50%)

# %% [markdown]
# ## Testing

# %%
#test DANN on the test data
DANN_test(feature_extractor, class_classifier, domain_classifier, test_loader, dataset='TARGET')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/lisa/bhartendu/adrl/A2/Domaain_Adaptation/Domain_Adversarial_Training_of_Neural_Network.ipynb Cell 57 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B10.64.35.99/home/lisa/bhartendu/adrl/A2/Domaain_Adaptation/Domain_Adversarial_Training_of_Neural_Network.ipynb#Y110sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> #test DANN on the test data
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.64.35.99/home/lisa/bhartendu/adrl/A2/Domaain_Adaptation/Domain_Adversarial_Training_of_Neural_Network.ipynb#Y110sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> DANN_test(feature_extractor, class_classifier, domain_classifier, test_loader, dataset='TARGET')
#
# NameError: name 'feature_extractor' is not defined

# %%
#test  DANN predictions on train data
DANN_test(feature_extractor, class_classifier, domain_classifier, train_loader, dataset='SOURCE')
